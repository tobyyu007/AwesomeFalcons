# %%
#code credits: Professor Richard Hull
# These are boiler plate imports that seem useful
# I should probably delete or comment out the ones that aren't used in this script...

import sys
import os
import subprocess
import shutil
# use shutil.rmtree(<path_to_folder>) to do an rm -r on the folder

import json
import csv
import yaml

import urllib

import pandas as pd
import numpy as np

import matplotlib as mpl
from cycler import cycler

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# sys.path.append('/Users/rick/HACKING/UTILITIES_IN_HACKING/')
# import utils_general


# this one gives a warning - not fixing for now
# from owlready2 import *

# next function is used to generate timestamps that can be used to
# create uniquely named directories and/or files
import datetime
def curr_timestamp():
    current_datetime = datetime.datetime.now()
    formatted_datetime = current_datetime.strftime("%Y-%m-%d_%H-%M-%S")
    return formatted_datetime


print('Initial imports successful')
# Out:
# Initial imports successful

# %%
def pull_useful(ginfo):  # should give as input the result.stdout from calling gdalinfo -json
    useful = {}
    useful['cornerCoordinates'] = ginfo['cornerCoordinates']
    useful['proj:transform'] = ginfo['stac']['proj:transform']
    useful['size'] = ginfo['size']
    useful['bbox'] = ginfo['stac']['proj:projjson']['bbox']
    useful['espgEncoding'] = ginfo['stac']['proj:epsg']
    return useful

# %%
from osgeo import gdal

work_dir = "/Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/"
pkl_file_path = '/Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/pkl_files/rain_df.pkl'
arr_sec = list(range(1, 44))
col_names = ['sector', 'year', 'rain']

rain_df = pd.DataFrame(columns=col_names)

file_names = os.listdir(work_dir)

# Filter for only .tif files
tif_files = [file for file in file_names if file.endswith('.tif')]

for file_name in tif_files:
    tif_file_name = file_name
    year = tif_file_name.split('_')[3].replace('.tif', '')
    ds = gdal.Open(work_dir + tif_file_name)
    cmd = 'gdal_translate -projwin'
    #39.2856,-122.1515 upper left 
    #39.2896,-121.7084 upper right
    #38.6845,-121.7559 lower left
    #38.6819,-121.5623 lower right
    leftLon = '-122.1515'
    upperLat = '39.2896'
    rightLon = '-121.5623'
    lowerLat = '38.6819'
    format = '-of GTiff'
    source = work_dir + tif_file_name
    clipped_file_name = tif_file_name.replace('.tif','')+'_c.tif'
    target = work_dir + 'clipped/' + clipped_file_name

    val = " ".join([cmd, leftLon, upperLat, rightLon, lowerLat, format, source, target])
    print(val)

    result = subprocess.run([val], shell=True, capture_output=True, text=True)

    print()
    #print(result.stdout)
    #print(result.stderr)

    val = " ".join(["gdalinfo", "-json", target])
    #print(val)
    result = subprocess.run([val], shell=True, capture_output=True, text=True)

    dict = json.loads(result.stdout)

    useful = pull_useful(dict)
    #print(json.dumps(useful, indent=2, sort_keys=True))

    dsc = gdal.Open(target)
    dcarray = np.array(dsc.GetRasterBand(1).ReadAsArray())
    
    '''
    plt.figure(figsize=(10,5))
    plt.imshow(dcarray) 

    plt.colorbar()
    plt.show()
    '''
    
    arr_prc = []
    for row in dcarray:
        arr_prc.extend(row)
    arr_prc = arr_prc[:43]

    arr_year = [year]*43

    temp_df = pd.DataFrame({
        'sector': arr_sec,
        'year': arr_year,
        'rain': arr_prc
    })

    rain_df = pd.concat([rain_df, temp_df])
    # Save the DataFrame as a pickle file
    rain_df.to_pickle(pkl_file_path)
# Out:
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2013.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2013_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2012.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2012_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2038.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2038_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2039.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2039_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2011.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2011_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2029.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2029_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2015.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2015_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2014.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2014_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2028.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2028_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2016.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2016_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2017.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2017_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2064.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2064_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2070.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2070_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2058.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2058_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2059.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2059_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2071.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2071_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2065.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2065_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2098.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2098_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2073.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2073_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2067.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2067_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2066.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2066_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2072.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2072_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2099.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2099_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2089.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2089_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2076.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2076_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2062.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2062_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2063.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2063_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2077.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2077_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2088.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2088_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2049.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2049_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2061.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2061_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2075.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2075_c.tif
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2074.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2074_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2060.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2060_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2048.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2048_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2086.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2086_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2092.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2092_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2045.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2045_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2051.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2051_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2079.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2079_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2078.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2078_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2050.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2050_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2044.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2044_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2093.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2093_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2087.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2087_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2091.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2091_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2085.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2085_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2052.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2052_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2046.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2046_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2047.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2047_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2053.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2053_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2084.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2084_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2090.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2090_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2094.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2094_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2080.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2080_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2057.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2057_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2043.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2043_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2042.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2042_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2056.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2056_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2081.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2081_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2095.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2095_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2083.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2083_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2097.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2097_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2068.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2068_c.tif
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2040.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2040_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2054.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2054_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2055.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2055_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2041.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2041_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2069.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2069_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2096.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2096_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2082.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2082_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2026.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2026_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2032.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2032_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2033.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2033_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2027.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2027_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2031.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2031_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2025.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2025_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2019.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2019_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2018.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2018_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2024.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2024_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2030.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2030_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2034.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2034_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2020.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2020_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2021.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2021_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2035.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2035_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2023.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2023_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2037.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2037_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2036.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2036_c.tif
#
# gdal_translate -projwin -122.1515 39.2896 -121.5623 38.6819 -of GTiff /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/prc_GFDL-ESM2M_rcp8p5_2022.tif /Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/Rain/clipped/prc_GFDL-ESM2M_rcp8p5_2022_c.tif

# %%
df = pd.read_pickle('/Users/kavya/Documents/ECS289L/Project2/GAEZ/tif_files/pkl_files/rain_df.pkl')
df
# Out:
#    sector  year rain
# 0       1  2013  556
# 1       2  2013  561
# 2       3  2013  560
# 3       4  2013  565
# 4       5  2013  569
# ..    ...   ...  ...
# 38     39  2022  690
# 39     40  2022  671
# 40     41  2022  682
# 41     42  2022  725
# 42     43  2022  809
#
# [3827 rows x 3 columns]
