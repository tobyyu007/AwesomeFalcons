# %%
import matplotlib.pyplot as plt

# Lasso 1.6628569854050963
# LR w/ ST 1.44834539493855
# LR w/ MM 0.16969383645502115
# RF 0.1234188227148637
# Gradient Boast Regressor 0.12112390483061733
models = ['Lasso', 'LR w/ ST', 'LR w/ MM', 'Random Forest', 'Gradient Boost Regressor']
rrmse = [1.6628569854050963, 1.44834539493855, 0.16969383645502115, 0.1234188227148637, 0.12112390483061733]

plt.figure(figsize=(10,8))
bar = plt.bar(models, rrmse, width=0.4)
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.3f' % height, ha='center', va='bottom', size = 12)


plt.ylabel("Test RRMSE")
plt.xlabel("model")
plt.title("Monthly")
# plt.legend()
plt.show()
plt.clf()

# %%
import matplotlib.pyplot as plt

# Lasso 1.6628569854050963
# LR w/ ST 1.44834539493855
# LR w/ MM 0.16969383645502115
# RF 0.1234188227148637
# Gradient Boast Regressor 0.12112390483061733
models = ['Lasso', 'LR w/ ST', 'LR w/ MM', 'Random Forest', 'Gradient Boost Regressor']
rrmse = [1.6104307681342398, 0.7906045427946263, 0.14646131773873533, 0.12398733924979972, 0.12485445975766]

plt.figure(figsize=(10,8))
bar = plt.bar(models, rrmse, width=0.4)
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.3f' % height, ha='center', va='bottom', size = 12)
plt.ylabel("Test RRMSE")
plt.xlabel("model")
plt.title("Weekly")
# plt.legend()
plt.show()
plt.clf()

# %%
import matplotlib.pyplot as plt

# Lasso 1.6628569854050963
# LR w/ ST 1.44834539493855
# LR w/ MM 0.16969383645502115
# RF 0.1234188227148637
# Gradient Boast Regressor 0.12112390483061733
models = ['Lasso', 'LR w/ ST', 'LR w/ MM', 'Random Forest', 'Gradient Boost Regressor']
rrmse = [1.7453601179345652, 1.5763132646775415, 0.2740157949452365, 0.22762371734264086, 0.22544688696712356]

plt.figure(figsize=(10,8))
bar = plt.bar(models, rrmse, width=0.4)
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.3f' % height, ha='center', va='bottom', size = 12)
plt.ylabel("Test RRMSE")
plt.xlabel("model")
# plt.legend()
plt.show()
plt.clf()
