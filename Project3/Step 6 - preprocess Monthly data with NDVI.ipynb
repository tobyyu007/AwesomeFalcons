# %% [markdown]
# ## import library

# %%
import pandas as pd

# %% [markdown]
# ## import data

# %% [markdown]
# ### yield

# %%
yield_dir = './yield_data/'
yield_file = 'wheat_yield_data_final.csv'

yield_df = pd.read_csv(yield_dir + yield_file)
print(yield_df.head())
print("-----")
soil_dir = './soil_data/'
soil_file = 'state_county_lon_lat_soil.csv'
soil_df = pd.read_csv(soil_dir + soil_file)
print(soil_df.head())
# Out:
#    year state_name county_name  yield
# 0  2000     KANSAS       ALLEN   40.0
# 1  2000     KANSAS    ANDERSON   44.0
# 2  2000     KANSAS    ATCHISON   44.0
# 3  2000     KANSAS      BARBER   37.0
# 4  2000     KANSAS      BARTON   44.0
# -----
#   state_name county_name         lon        lat  nutr_ret_high  \
# 0     KANSAS    CHEYENNE -101.757549  39.795580             10
# 1     KANSAS     DECATUR -100.472769  39.794053             10
# 2     KANSAS      GRAHAM  -99.898062  39.340620             10
# 3     KANSAS      NORTON  -99.910003  39.794470             10
# 4     KANSAS     RAWLINS -101.099472  39.790480             10
#
#    suit_irrig_high_soy  AEZ_1  AEZ_2  AEZ_3  AEZ_4  ...  SQL_1  SQL_2  SQL_3  \
# 0                10000  False  False  False  False  ...  False  False  False
# 1                 8536  False  False  False  False  ...  False  False  False
# 2                 7778  False  False  False  False  ...  False  False  False
# 3                 7778  False  False  False  False  ...  False  False  False
# 4                10000  False  False  False  False  ...  False  False  False
#
#    SQL_4  SQL_5  SQL_6  SQL_7  SQL_8  SQL_9  SQL_10
# 0  False  False  False  False   True  False   False
# 1  False  False  False  False   True  False   False
# 2  False  False  False  False   True  False   False
# 3  False  False  False  False   True  False   False
# 4  False  False  False  False   True  False   False
#
# [5 rows x 47 columns]

# %% [markdown]
# ### weather data

# %%
lon_lat_dir = './lon_lat_data/'
yscyll_filename = 'year_state_county_yield_lon_lat.csv'

ndvi_dir = './remote_s/'
ndvi_filename = 'converted_ndvi.csv'

df_yscyll = pd.read_csv(lon_lat_dir + yscyll_filename)
df_ndvi = pd.read_csv(ndvi_dir + ndvi_filename)

temp_df = pd.merge(df_yscyll, df_ndvi, on=['state_name','county_name', 'year'],how='right')
df_yscyll = temp_df.dropna()

weather_dir = './weather_data/'
wdtemplate = r'weather-data-for-index__{padded}.csv'

w_df = {}
for i in range(0,len(df_yscyll)):
    try:
        padded = str(i).zfill(4)
        w_df[i] = pd.read_csv(weather_dir + wdtemplate.format(padded=padded))
        # Want to have a name for the index of my dataframe
        w_df[i].rename(columns={'Unnamed: 0': 'date'}, 
                       inplace=True)
    # w_df[i] = w_df[i].rename_axis(index='DATE')
    except:
        print(f'{padded} is missing')
print()
print(w_df[4].shape)
print(w_df[4].head())
# Out:
# 8594 is missing
# 8595 is missing
# 8596 is missing
# 8597 is missing
# 8598 is missing
# 8599 is missing
# 8600 is missing
# 8601 is missing
# 8602 is missing
# 8603 is missing
# 8604 is missing
# 8605 is missing
# 8606 is missing
# 8607 is missing
# 8608 is missing
# 8609 is missing
# 8610 is missing
# 8611 is missing
# 8612 is missing
# 8613 is missing
# 8614 is missing
# 8615 is missing
# 8616 is missing
# 8617 is missing
# 8618 is missing
# 8619 is missing
# 8620 is missing
# 8621 is missing
# 8622 is missing
# 8623 is missing
# 8624 is missing
# 8625 is missing
# 8626 is missing
# 8627 is missing
# 8628 is missing
# 8629 is missing
# 8630 is missing
# 8631 is missing
# 8632 is missing
# 8633 is missing
# 8634 is missing
# 8635 is missing
# 8636 is missing
# 8637 is missing
# 8638 is missing
# 8639 is missing
# 8640 is missing
# 8641 is missing
# 8642 is missing
# 8643 is missing
# 8644 is missing
# 8645 is missing
# 8646 is missing
# 8647 is missing
# 8648 is missing
# 8649 is missing
# 8650 is missing
# 8651 is missing
# 8652 is missing
# 8653 is missing
# 8654 is missing
# 8655 is missing
# 8656 is missing
# 8657 is missing
# 8658 is missing
# 8659 is missing
# 8660 is missing
# 8661 is missing
# 8662 is missing
# 8663 is missing
# 8664 is missing
# 8665 is missing
# 8666 is missing
# 8667 is missing
# 8668 is missing
# 8669 is missing
# 8670 is missing
# 8671 is missing
# 8672 is missing
# 8673 is missing
# 8674 is missing
# 8675 is missing
# 8676 is missing
# 8677 is missing
# 8678 is missing
# 8679 is missing
# 8680 is missing
# 8681 is missing
# 8682 is missing
# 8683 is missing
# 8684 is missing
# 8685 is missing
# 8686 is missing
# 8687 is missing
# 8688 is missing
# 8689 is missing
# 8690 is missing
# 8691 is missing
# 8692 is missing
# 8693 is missing
# 8694 is missing
# 8695 is missing
# 8696 is missing
# 8697 is missing
# 8698 is missing
# 8699 is missing
# 8700 is missing
# 8701 is missing
# 8702 is missing
# 8703 is missing
# 8704 is missing
# 8705 is missing
# 8706 is missing
# 8707 is missing
# 8708 is missing
# 8709 is missing
# 8710 is missing
# 8711 is missing
# 8712 is missing
# 8713 is missing
# 8714 is missing
# 8715 is missing
# 8716 is missing
# 8717 is missing
# 8718 is missing
# 8719 is missing
# 8720 is missing
# 8721 is missing
# 8722 is missing
# 8723 is missing
# 8724 is missing
# 8725 is missing
# 8726 is missing
# 8727 is missing
# 8728 is missing
# 8729 is missing
# 8730 is missing
# 8731 is missing
# 8732 is missing
# 8733 is missing
# 8734 is missing
# 8735 is missing
# 8736 is missing
# 8737 is missing
# 8738 is missing
# 8739 is missing
# 8740 is missing
# 8741 is missing
# 8742 is missing
# 8743 is missing
# 8744 is missing
# 8745 is missing
# 8746 is missing
# 8747 is missing
# 8748 is missing
# 8749 is missing
# 8750 is missing
# 8751 is missing
# 8752 is missing
# 8753 is missing
# 8754 is missing
# 8755 is missing
# 8756 is missing
# 8757 is missing
# 8758 is missing
# 8759 is missing
# 8760 is missing
# 8761 is missing
# 8762 is missing
# 8763 is missing
# 8764 is missing
# 8765 is missing
# 8766 is missing
# 8767 is missing
# 8768 is missing
# 8769 is missing
# 8770 is missing
# 8771 is missing
# 8772 is missing
# 8773 is missing
# 8774 is missing
# 8775 is missing
# 8776 is missing
# 8777 is missing
# 8778 is missing
# 8779 is missing
# 8780 is missing
# 8781 is missing
# 8782 is missing
# 8783 is missing
# 8784 is missing
# 8785 is missing
# 8786 is missing
# 8787 is missing
# 8788 is missing
# 8789 is missing
# 8790 is missing
# 8791 is missing
# 8792 is missing
# 8793 is missing
# 8794 is missing
# 8795 is missing
# 8796 is missing
# 8797 is missing
# 8798 is missing
# 8799 is missing
# 8800 is missing
# 8801 is missing
# 8802 is missing
# 8803 is missing
# 8804 is missing
# 8805 is missing
# 8806 is missing
# 8807 is missing
# 8808 is missing
# 8809 is missing
# 8810 is missing
# 8811 is missing
# 8812 is missing
# 8813 is missing
# 8814 is missing
# 8815 is missing
# 8816 is missing
# 8817 is missing
# 8818 is missing
# 8819 is missing
# 8820 is missing
# 8821 is missing
# 8822 is missing
# 8823 is missing
# 8824 is missing
# 8825 is missing
# 8826 is missing
# 8827 is missing
# 8828 is missing
# 8829 is missing
# 8830 is missing
# 8831 is missing
# 8832 is missing
# 8833 is missing
# 8834 is missing
# 8835 is missing
# 8836 is missing
# 8837 is missing
# 8838 is missing
# 8839 is missing
# 8840 is missing
# 8841 is missing
# 8842 is missing
# 8843 is missing
# 8844 is missing
# 8845 is missing
# 8846 is missing
# 8847 is missing
# 8848 is missing
# 8849 is missing
# 8850 is missing
# 8851 is missing
# 8852 is missing
# 8853 is missing
# 8854 is missing
# 8855 is missing
# 8856 is missing
# 8857 is missing
# 8858 is missing
# 8859 is missing
# 8860 is missing
# 8861 is missing
# 8862 is missing
# 8863 is missing
# 8864 is missing
# 8865 is missing
# 8866 is missing
# 8867 is missing
# 8868 is missing
# 8869 is missing
# 8870 is missing
# 8871 is missing
# 8872 is missing
# 8873 is missing
# 8874 is missing
# 8875 is missing
# 8876 is missing
# 8877 is missing
# 8878 is missing
# 8879 is missing
# 8880 is missing
# 8881 is missing
# 8882 is missing
# 8883 is missing
# 8884 is missing
# 8885 is missing
# 8886 is missing
# 8887 is missing
# 8888 is missing
# 8889 is missing
# 8890 is missing
# 8891 is missing
# 8892 is missing
# 8893 is missing
# 8894 is missing
# 8895 is missing
# 8896 is missing
# 8897 is missing
# 8898 is missing
# 8899 is missing
# 8900 is missing
# 8901 is missing
# 8902 is missing
# 8903 is missing
# 8904 is missing
# 8905 is missing
# 8906 is missing
# 8907 is missing
# 8908 is missing
# 8909 is missing
# 8910 is missing
# 8911 is missing
# 8912 is missing
# 8913 is missing
# 8914 is missing
# 8915 is missing
# 8916 is missing
# 8917 is missing
# 8918 is missing
# 8919 is missing
# 8920 is missing
# 8921 is missing
# 8922 is missing
# 8923 is missing
# 8924 is missing
# 8925 is missing
# 8926 is missing
# 8927 is missing
# 8928 is missing
# 8929 is missing
# 8930 is missing
# 8931 is missing
# 8932 is missing
# 8933 is missing
# 8934 is missing
# 8935 is missing
# 8936 is missing
# 8937 is missing
# 8938 is missing
# 8939 is missing
# 8940 is missing
# 8941 is missing
# 8942 is missing
# 8943 is missing
# 8944 is missing
# 8945 is missing
# 8946 is missing
# 8947 is missing
# 8948 is missing
# 8949 is missing
# 8950 is missing
# 8951 is missing
# 8952 is missing
# 8953 is missing
# 8954 is missing
# 8955 is missing
# 8956 is missing
# 8957 is missing
# 8958 is missing
# 8959 is missing
# 8960 is missing
# 8961 is missing
# 8962 is missing
# 8963 is missing
# 8964 is missing
# 8965 is missing
# 8966 is missing
# 8967 is missing
# 8968 is missing
# 8969 is missing
# 8970 is missing
# 8971 is missing
# 8972 is missing
# 8973 is missing
# 8974 is missing
# 8975 is missing
# 8976 is missing
# 8977 is missing
# 8978 is missing
# 8979 is missing
# 8980 is missing
# 8981 is missing
# 8982 is missing
# 8983 is missing
# 8984 is missing
# 8985 is missing
# 8986 is missing
# 8987 is missing
# 8988 is missing
# 8989 is missing
# 8990 is missing
# 8991 is missing
# 8992 is missing
# 8993 is missing
# 8994 is missing
# 8995 is missing
# 8996 is missing
# 8997 is missing
# 8998 is missing
# 8999 is missing
# 9000 is missing
# 9001 is missing
# 9002 is missing
# 9003 is missing
# 9004 is missing
# 9005 is missing
# 9006 is missing
# 9007 is missing
# 9008 is missing
# 9009 is missing
# 9010 is missing
# 9011 is missing
# 9012 is missing
# 9013 is missing
# 9014 is missing
# 9015 is missing
# 9016 is missing
# 9017 is missing
# 9018 is missing
# 9019 is missing
# 9020 is missing
# 9021 is missing
# 9022 is missing
# 9023 is missing
# 9024 is missing
# 9025 is missing
# 9026 is missing
# 9027 is missing
# 9028 is missing
# 9029 is missing
# 9030 is missing
# 9031 is missing
# 9032 is missing
# 9033 is missing
# 9034 is missing
# 9035 is missing
# 9036 is missing
# 9037 is missing
# 9038 is missing
# 9039 is missing
# 9040 is missing
# 9041 is missing
# 9042 is missing
# 9043 is missing
# 9044 is missing
# 9045 is missing
# 9046 is missing
# 9047 is missing
# 9048 is missing
# 9049 is missing
# 9050 is missing
# 9051 is missing
# 9052 is missing
# 9053 is missing
# 9054 is missing
# 9055 is missing
# 9056 is missing
# 9057 is missing
# 9058 is missing
# 9059 is missing
# 9060 is missing
# 9061 is missing
# 9062 is missing
# 9063 is missing
# 9064 is missing
# 9065 is missing
# 9066 is missing
# 9067 is missing
# 9068 is missing
# 9069 is missing
# 9070 is missing
# 9071 is missing
# 9072 is missing
# 9073 is missing
# 9074 is missing
# 9075 is missing
# 9076 is missing
# 9077 is missing
# 9078 is missing
# 9079 is missing
# 9080 is missing
# 9081 is missing
# 9082 is missing
# 9083 is missing
# 9084 is missing
# 9085 is missing
# 9086 is missing
# 9087 is missing
# 9088 is missing
# 9089 is missing
# 9090 is missing
# 9091 is missing
# 9092 is missing
# 9093 is missing
# 9094 is missing
# 9095 is missing
# 9096 is missing
# 9097 is missing
# 9098 is missing
# 9099 is missing
# 9100 is missing
# 9101 is missing
# 9102 is missing
# 9103 is missing
# 9104 is missing
# 9105 is missing
# 9106 is missing
# 9107 is missing
# 9108 is missing
# 9109 is missing
# 9110 is missing
# 9111 is missing
# 9112 is missing
# 9113 is missing
# 9114 is missing
# 9115 is missing
# 9116 is missing
# 9117 is missing
# 9118 is missing
# 9119 is missing
# 9120 is missing
# 9121 is missing
# 9122 is missing
# 9123 is missing
# 9124 is missing
# 9125 is missing
# 9126 is missing
# 9127 is missing
# 9128 is missing
# 9129 is missing
# 9130 is missing
# 9131 is missing
# 9132 is missing
# 9133 is missing
# 9134 is missing
# 9135 is missing
# 9136 is missing
# 9137 is missing
# 9138 is missing
# 9139 is missing
# 9140 is missing
# 9141 is missing
# 9142 is missing
# 9143 is missing
# 9144 is missing
# 9145 is missing
# 9146 is missing
# 9147 is missing
# 9148 is missing
# 9149 is missing
# 9150 is missing
# 9151 is missing
# 9152 is missing
# 9153 is missing
# 9154 is missing
# 9155 is missing
# 9156 is missing
# 9157 is missing
# 9158 is missing
# 9159 is missing
# 9160 is missing
# 9161 is missing
# 9162 is missing
# 9163 is missing
# 9164 is missing
# 9165 is missing
# 9166 is missing
# 9167 is missing
# 9168 is missing
# 9169 is missing
# 9170 is missing
# 9171 is missing
# 9172 is missing
# 9173 is missing
# 9174 is missing
# 9175 is missing
# 9176 is missing
# 9177 is missing
# 9178 is missing
# 9179 is missing
# 9180 is missing
# 9181 is missing
# 9182 is missing
# 9183 is missing
# 9184 is missing
# 9185 is missing
# 9186 is missing
# 9187 is missing
# 9188 is missing
# 9189 is missing
# 9190 is missing
# 9191 is missing
# 9192 is missing
# 9193 is missing
# 9194 is missing
# 9195 is missing
# 9196 is missing
# 9197 is missing
# 9198 is missing
# 9199 is missing
# 9200 is missing
# 9201 is missing
# 9202 is missing
# 9203 is missing
# 9204 is missing
# 9205 is missing
# 9206 is missing
# 9207 is missing
# 9208 is missing
# 9209 is missing
# 9210 is missing
# 9211 is missing
# 9212 is missing
# 9213 is missing
# 9214 is missing
# 9215 is missing
# 9216 is missing
# 9217 is missing
# 9218 is missing
# 9219 is missing
# 9220 is missing
# 9221 is missing
# 9222 is missing
# 9223 is missing
# 9224 is missing
# 9225 is missing
# 9226 is missing
# 9227 is missing
# 9228 is missing
# 9229 is missing
# 9230 is missing
# 9231 is missing
# 9232 is missing
# 9233 is missing
# 9234 is missing
# 9235 is missing
# 9236 is missing
# 9237 is missing
# 9238 is missing
# 9239 is missing
# 9240 is missing
# 9241 is missing
# 9242 is missing
# 9243 is missing
# 9244 is missing
# 9245 is missing
# 9246 is missing
# 9247 is missing
# 9248 is missing
# 9249 is missing
# 9250 is missing
# 9251 is missing
# 9252 is missing
# 9253 is missing
# 9254 is missing
# 9255 is missing
# 9256 is missing
# 9257 is missing
# 9258 is missing
# 9259 is missing
# 9260 is missing
# 9261 is missing
# 9262 is missing
# 9263 is missing
# 9264 is missing
# 9265 is missing
# 9266 is missing
# 9267 is missing
# 9268 is missing
# 9269 is missing
# 9270 is missing
# 9271 is missing
# 9272 is missing
# 9273 is missing
# 9274 is missing
# 9275 is missing
# 9276 is missing
# 9277 is missing
# 9278 is missing
# 9279 is missing
# 9280 is missing
# 9281 is missing
# 9282 is missing
# 9283 is missing
# 9284 is missing
# 9285 is missing
# 9286 is missing
# 9287 is missing
# 9288 is missing
# 9289 is missing
# 9290 is missing
# 9291 is missing
# 9292 is missing
# 9293 is missing
# 9294 is missing
# 9295 is missing
# 9296 is missing
# 9297 is missing
# 9298 is missing
# 9299 is missing
# 9300 is missing
# 9301 is missing
# 9302 is missing
# 9303 is missing
# 9304 is missing
# 9305 is missing
# 9306 is missing
# 9307 is missing
# 9308 is missing
# 9309 is missing
# 9310 is missing
# 9311 is missing
# 9312 is missing
# 9313 is missing
# 9314 is missing
# 9315 is missing
# 9316 is missing
# 9317 is missing
# 9318 is missing
# 9319 is missing
# 9320 is missing
# 9321 is missing
# 9322 is missing
# 9323 is missing
# 9324 is missing
# 9325 is missing
# 9326 is missing
# 9327 is missing
# 9328 is missing
# 9329 is missing
# 9330 is missing
# 9331 is missing
# 9332 is missing
# 9333 is missing
# 9334 is missing
# 9335 is missing
# 9336 is missing
# 9337 is missing
# 9338 is missing
# 9339 is missing
# 9340 is missing
# 9341 is missing
# 9342 is missing
# 9343 is missing
# 9344 is missing
# 9345 is missing
# 9346 is missing
# 9347 is missing
# 9348 is missing
# 9349 is missing
# 9350 is missing
# 9351 is missing
# 9352 is missing
# 9353 is missing
# 9354 is missing
# 9355 is missing
# 9356 is missing
# 9357 is missing
# 9358 is missing
# 9359 is missing
# 9360 is missing
# 9361 is missing
# 9362 is missing
# 9363 is missing
# 9364 is missing
# 9365 is missing
# 9366 is missing
# 9367 is missing
# 9368 is missing
# 9369 is missing
# 9370 is missing
# 9371 is missing
# 9372 is missing
# 9373 is missing
# 9374 is missing
# 9375 is missing
# 9376 is missing
# 9377 is missing
# 9378 is missing
# 9379 is missing
# 9380 is missing
# 9381 is missing
# 9382 is missing
# 9383 is missing
# 9384 is missing
# 9385 is missing
# 9386 is missing
# 9387 is missing
# 9388 is missing
# 9389 is missing
# 9390 is missing
# 9391 is missing
# 9392 is missing
# 9393 is missing
# 9394 is missing
# 9395 is missing
# 9396 is missing
# 9397 is missing
# 9398 is missing
# 9399 is missing
# 9400 is missing
# 9401 is missing
# 9402 is missing
# 9403 is missing
# 9404 is missing
# 9405 is missing
# 9406 is missing
# 9407 is missing
# 9408 is missing
# 9409 is missing
# 9410 is missing
# 9411 is missing
# 9412 is missing
# 9413 is missing
# 9414 is missing
# 9415 is missing
# 9416 is missing
# 9417 is missing
# 9418 is missing
# 9419 is missing
# 9420 is missing
# 9421 is missing
# 9422 is missing
# 9423 is missing
# 9424 is missing
# 9425 is missing
# 9426 is missing
# 9427 is missing
# 9428 is missing
# 9429 is missing
# 9430 is missing
# 9431 is missing
# 9432 is missing
# 9433 is missing
# 9434 is missing
# 9435 is missing
# 9436 is missing
# 9437 is missing
# 9438 is missing
# 9439 is missing
# 9440 is missing
# 9441 is missing
# 9442 is missing
# 9443 is missing
# 9444 is missing
# 9445 is missing
# 9446 is missing
# 9447 is missing
# 9448 is missing
# 9449 is missing
# 9450 is missing
# 9451 is missing
# 9452 is missing
# 9453 is missing
# 9454 is missing
# 9455 is missing
# 9456 is missing
# 9457 is missing
# 9458 is missing
# 9459 is missing
# 9460 is missing
# 9461 is missing
# 9462 is missing
# 9463 is missing
# 9464 is missing
# 9465 is missing
# 9466 is missing
# 9467 is missing
# 9468 is missing
# 9469 is missing
# 9470 is missing
# 9471 is missing
# 9472 is missing
# 9473 is missing
# 9474 is missing
# 9475 is missing
# 9476 is missing
# 9477 is missing
# 9478 is missing
# 9479 is missing
# 9480 is missing
# 9481 is missing
# 9482 is missing
# 9483 is missing
# 9484 is missing
# 9485 is missing
# 9486 is missing
# 9487 is missing
# 9488 is missing
# 9489 is missing
# 9490 is missing
# 9491 is missing
# 9492 is missing
# 9493 is missing
# 9494 is missing
# 9495 is missing
# 9496 is missing
# 9497 is missing
# 9498 is missing
# 9499 is missing
# 9500 is missing
# 9501 is missing
# 9502 is missing
# 9503 is missing
# 9504 is missing
# 9505 is missing
# 9506 is missing
# 9507 is missing
# 9508 is missing
# 9509 is missing
# 9510 is missing
# 9511 is missing
# 9512 is missing
# 9513 is missing
# 9514 is missing
# 9515 is missing
# 9516 is missing
# 9517 is missing
# 9518 is missing
# 9519 is missing
# 9520 is missing
# 9521 is missing
# 9522 is missing
# 9523 is missing
# 9524 is missing
# 9525 is missing
# 9526 is missing
# 9527 is missing
# 9528 is missing
# 9529 is missing
# 9530 is missing
# 9531 is missing
# 9532 is missing
# 9533 is missing
# 9534 is missing
# 9535 is missing
# 9536 is missing
# 9537 is missing
# 9538 is missing
# 9539 is missing
# 9540 is missing
# 9541 is missing
# 9542 is missing
# 9543 is missing
# 9544 is missing
# 9545 is missing
# 9546 is missing
# 9547 is missing
# 9548 is missing
# 9549 is missing
# 9550 is missing
# 9551 is missing
# 9552 is missing
# 9553 is missing
# 9554 is missing
# 9555 is missing
# 9556 is missing
# 9557 is missing
# 9558 is missing
# 9559 is missing
# 9560 is missing
# 9561 is missing
# 9562 is missing
# 9563 is missing
# 9564 is missing
# 9565 is missing
# 9566 is missing
# 9567 is missing
# 9568 is missing
# 9569 is missing
# 9570 is missing
# 9571 is missing
# 9572 is missing
# 9573 is missing
# 9574 is missing
# 9575 is missing
# 9576 is missing
# 9577 is missing
# 9578 is missing
# 9579 is missing
# 9580 is missing
# 9581 is missing
# 9582 is missing
# 9583 is missing
# 9584 is missing
# 9585 is missing
# 9586 is missing
# 9587 is missing
# 9588 is missing
# 9589 is missing
# 9590 is missing
# 9591 is missing
# 9592 is missing
# 9593 is missing
# 9594 is missing
# 9595 is missing
# 9596 is missing
# 9597 is missing
# 9598 is missing
# 9599 is missing
# 9600 is missing
# 9601 is missing
# 9602 is missing
# 9603 is missing
# 9604 is missing
# 9605 is missing
# 9606 is missing
# 9607 is missing
# 9608 is missing
# 9609 is missing
# 9610 is missing
# 9611 is missing
# 9612 is missing
# 9613 is missing
# 9614 is missing
# 9615 is missing
# 9616 is missing
# 9617 is missing
# 9618 is missing
# 9619 is missing
# 9620 is missing
# 9621 is missing
# 9622 is missing
# 9623 is missing
# 9624 is missing
# 9625 is missing
# 9626 is missing
# 9627 is missing
# 9628 is missing
# 9629 is missing
# 9630 is missing
# 9631 is missing
# 9632 is missing
# 9633 is missing
# 9634 is missing
# 9635 is missing
# 9636 is missing
# 9637 is missing
# 9638 is missing
# 9639 is missing
# 9640 is missing
# 9641 is missing
# 9642 is missing
# 9643 is missing
# 9644 is missing
# 9645 is missing
# 9646 is missing
# 9647 is missing
# 9648 is missing
# 9649 is missing
# 9650 is missing
# 9651 is missing
# 9652 is missing
# 9653 is missing
# 9654 is missing
# 9655 is missing
# 9656 is missing
# 9657 is missing
# 9658 is missing
# 9659 is missing
# 9660 is missing
# 9661 is missing
# 9662 is missing
# 9663 is missing
# 9664 is missing
# 9665 is missing
# 9666 is missing
# 9667 is missing
# 9668 is missing
# 9669 is missing
# 9670 is missing
# 9671 is missing
# 9672 is missing
# 9673 is missing
# 9674 is missing
# 9675 is missing
# 9676 is missing
# 9677 is missing
# 9678 is missing
# 9679 is missing
# 9680 is missing
# 9681 is missing
# 9682 is missing
# 9683 is missing
# 9684 is missing
# 9685 is missing
# 9686 is missing
# 9687 is missing
# 9688 is missing
# 9689 is missing
# 9690 is missing
# 9691 is missing
# 9692 is missing
# 9693 is missing
# 9694 is missing
# 9695 is missing
# 9696 is missing
# 9697 is missing
# 9698 is missing
# 9699 is missing
# 9700 is missing
# 9701 is missing
# 9702 is missing
# 9703 is missing
# 9704 is missing
# 9705 is missing
# 9706 is missing
# 9707 is missing
# 9708 is missing
# 9709 is missing
# 9710 is missing
# 9711 is missing
# 9712 is missing
# 9713 is missing
# 9714 is missing
# 9715 is missing
# 9716 is missing
# 9717 is missing
# 9718 is missing
# 9719 is missing
# 9720 is missing
# 9721 is missing
# 9722 is missing
# 9723 is missing
# 9724 is missing
# 9725 is missing
# 9726 is missing
# 9727 is missing
# 9728 is missing
# 9729 is missing
# 9730 is missing
# 9731 is missing
# 9732 is missing
# 9733 is missing
# 9734 is missing
# 9735 is missing
# 9736 is missing
# 9737 is missing
# 9738 is missing
# 9739 is missing
# 9740 is missing
# 9741 is missing
# 9742 is missing
# 9743 is missing
# 9744 is missing
# 9745 is missing
# 9746 is missing
# 9747 is missing
# 9748 is missing
# 9749 is missing
# 9750 is missing
# 9751 is missing
# 9752 is missing
# 9753 is missing
# 9754 is missing
# 9755 is missing
# 9756 is missing
# 9757 is missing
# 9758 is missing
# 9759 is missing
# 9760 is missing
# 9761 is missing
# 9762 is missing
# 9763 is missing
# 9764 is missing
# 9765 is missing
# 9766 is missing
# 9767 is missing
# 9768 is missing
# 9769 is missing
# 9770 is missing
# 9771 is missing
# 9772 is missing
# 9773 is missing
# 9774 is missing
# 9775 is missing
# 9776 is missing
# 9777 is missing
# 9778 is missing
# 9779 is missing
# 9780 is missing
# 9781 is missing
# 9782 is missing
# 9783 is missing
# 9784 is missing
# 9785 is missing
# 9786 is missing
# 9787 is missing
# 9788 is missing
# 9789 is missing
# 9790 is missing
# 9791 is missing
# 9792 is missing
# 9793 is missing
# 9794 is missing
# 9795 is missing
# 9796 is missing
# 9797 is missing
# 9798 is missing
# 9799 is missing
# 9800 is missing
# 9801 is missing
# 9802 is missing
# 9803 is missing
# 9804 is missing
# 9805 is missing
# 9806 is missing
# 9807 is missing
# 9808 is missing
# 9809 is missing
# 9810 is missing
# 9811 is missing
# 9812 is missing
# 9813 is missing
# 9814 is missing
# 9815 is missing
# 9816 is missing
# 9817 is missing
# 9818 is missing
# 9819 is missing
# 9820 is missing
# 9821 is missing
# 9822 is missing
# 9823 is missing
# 9824 is missing
# 9825 is missing
# 9826 is missing
# 9827 is missing
# 9828 is missing
# 9829 is missing
# 9830 is missing
# 9831 is missing
# 9832 is missing
# 9833 is missing
# 9834 is missing
# 9835 is missing
# 9836 is missing
# 9837 is missing
# 9838 is missing
# 9839 is missing
# 9840 is missing
# 9841 is missing
# 9842 is missing
# 9843 is missing
# 9844 is missing
# 9845 is missing
# 9846 is missing
# 9847 is missing
# 9848 is missing
# 9849 is missing
# 9850 is missing
# 9851 is missing
# 9852 is missing
# 9853 is missing
# 9854 is missing
# 9855 is missing
# 9856 is missing
# 9857 is missing
# 9858 is missing
# 9859 is missing
# 9860 is missing
# 9861 is missing
# 9862 is missing
# 9863 is missing
# 9864 is missing
# 9865 is missing
# 9866 is missing
# 9867 is missing
# 9868 is missing
# 9869 is missing
# 9870 is missing
# 9871 is missing
# 9872 is missing
# 9873 is missing
# 9874 is missing
# 9875 is missing
# 9876 is missing
# 9877 is missing
# 9878 is missing
# 9879 is missing
# 9880 is missing
# 9881 is missing
# 9882 is missing
# 9883 is missing
# 9884 is missing
# 9885 is missing
# 9886 is missing
# 9887 is missing
# 9888 is missing
# 9889 is missing
# 9890 is missing
# 9891 is missing
# 9892 is missing
# 9893 is missing
# 9894 is missing
# 9895 is missing
# 9896 is missing
# 9897 is missing
# 9898 is missing
# 9899 is missing
# 9900 is missing
# 9901 is missing
# 9902 is missing
# 9903 is missing
# 9904 is missing
# 9905 is missing
# 9906 is missing
# 9907 is missing
# 9908 is missing
# 9909 is missing
# 9910 is missing
# 9911 is missing
# 9912 is missing
# 9913 is missing
# 9914 is missing
# 9915 is missing
# 9916 is missing
# 9917 is missing
# 9918 is missing
# 9919 is missing
# 9920 is missing
# 9921 is missing
# 9922 is missing
# 9923 is missing
# 9924 is missing
# 9925 is missing
# 9926 is missing
# 9927 is missing
# 9928 is missing
# 9929 is missing
# 9930 is missing
# 9931 is missing
# 9932 is missing
# 9933 is missing
# 9934 is missing
# 9935 is missing
# 9936 is missing
# 9937 is missing
# 9938 is missing
# 9939 is missing
# 9940 is missing
# 9941 is missing
# 9942 is missing
# 9943 is missing
# 9944 is missing
# 9945 is missing
# 9946 is missing
# 9947 is missing
# 9948 is missing
# 9949 is missing
# 9950 is missing
# 9951 is missing
# 9952 is missing
# 9953 is missing
# 9954 is missing
# 9955 is missing
# 9956 is missing
# 9957 is missing
# 9958 is missing
# 9959 is missing
# 9960 is missing
# 9961 is missing
# 9962 is missing
# 9963 is missing
# 9964 is missing
# 9965 is missing
# 9966 is missing
# 9967 is missing
# 9968 is missing
# 9969 is missing
# 9970 is missing
# 9971 is missing
# 9972 is missing
# 9973 is missing
# 9974 is missing
# 9975 is missing
# 9976 is missing
# 9977 is missing
# 9978 is missing
# 9979 is missing
# 9980 is missing
# 9981 is missing
# 9982 is missing
# 9983 is missing
# 9984 is missing
# 9985 is missing
# 9986 is missing
# 9987 is missing
# 9988 is missing
# 9989 is missing
# 9990 is missing
# 9991 is missing
# 9992 is missing
# 9993 is missing
# 9994 is missing
# 9995 is missing
# 9996 is missing
# 9997 is missing
# 9998 is missing
# 9999 is missing
# 10000 is missing
# 10001 is missing
# 10002 is missing
# 10003 is missing
# 10004 is missing
# 10005 is missing
# 10006 is missing
# 10007 is missing
# 10008 is missing
# 10009 is missing
# 10010 is missing
# 10011 is missing
# 10012 is missing
# 10013 is missing
# 10014 is missing
# 10015 is missing
# 10016 is missing
# 10017 is missing
# 10018 is missing
# 10019 is missing
# 10020 is missing
# 10021 is missing
# 10022 is missing
# 10023 is missing
# 10024 is missing
# 10025 is missing
# 10026 is missing
# 10027 is missing
# 10028 is missing
# 10029 is missing
# 10030 is missing
# 10031 is missing
# 10032 is missing
# 10033 is missing
# 10034 is missing
# 10035 is missing
# 10036 is missing
# 10037 is missing
# 10038 is missing
# 10039 is missing
# 10040 is missing
# 10041 is missing
# 10042 is missing
# 10043 is missing
# 10044 is missing
# 10045 is missing
# 10046 is missing
# 10047 is missing
# 10048 is missing
# 10049 is missing
# 10050 is missing
# 10051 is missing
# 10052 is missing
# 10053 is missing
# 10054 is missing
# 10055 is missing
# 10056 is missing
# 10057 is missing
# 10058 is missing
# 10059 is missing
# 10060 is missing
# 10061 is missing
# 10062 is missing
# 10063 is missing
# 10064 is missing
# 10065 is missing
# 10066 is missing
# 10067 is missing
# 10068 is missing
# 10069 is missing
# 10070 is missing
# 10071 is missing
# 10072 is missing
# 10073 is missing
# 10074 is missing
# 10075 is missing
# 10076 is missing
# 10077 is missing
# 10078 is missing
# 10079 is missing
# 10080 is missing
# 10081 is missing
# 10082 is missing
# 10083 is missing
# 10084 is missing
# 10085 is missing
# 10086 is missing
# 10087 is missing
# 10088 is missing
# 10089 is missing
# 10090 is missing
# 10091 is missing
# 10092 is missing
# 10093 is missing
# 10094 is missing
# 10095 is missing
# 10096 is missing
# 10097 is missing
# 10098 is missing
# 10099 is missing
# 10100 is missing
# 10101 is missing
# 10102 is missing
# 10103 is missing
# 10104 is missing
# 10105 is missing
# 10106 is missing
# 10107 is missing
# 10108 is missing
# 10109 is missing
# 10110 is missing
# 10111 is missing
# 10112 is missing
# 10113 is missing
# 10114 is missing
# 10115 is missing
# 10116 is missing
# 10117 is missing
# 10118 is missing
# 10119 is missing
# 10120 is missing
# 10121 is missing
# 10122 is missing
# 10123 is missing
# 10124 is missing
# 10125 is missing
# 10126 is missing
# 10127 is missing
# 10128 is missing
# 10129 is missing
# 10130 is missing
# 10131 is missing
# 10132 is missing
# 10133 is missing
# 10134 is missing
# 10135 is missing
# 10136 is missing
# 10137 is missing
# 10138 is missing
# 10139 is missing
# 10140 is missing
# 10141 is missing
# 10142 is missing
# 10143 is missing
# 10144 is missing
# 10145 is missing
# 10146 is missing
# 10147 is missing
# 10148 is missing
# 10149 is missing
# 10150 is missing
# 10151 is missing
# 10152 is missing
# 10153 is missing
# 10154 is missing
# 10155 is missing
# 10156 is missing
# 10157 is missing
# 10158 is missing
# 10159 is missing
# 10160 is missing
# 10161 is missing
# 10162 is missing
# 10163 is missing
# 10164 is missing
# 10165 is missing
# 10166 is missing
# 10167 is missing
# 10168 is missing
# 10169 is missing
# 10170 is missing
# 10171 is missing
# 10172 is missing
# 10173 is missing
# 10174 is missing
# 10175 is missing
# 10176 is missing
# 10177 is missing
# 10178 is missing
# 10179 is missing
# 10180 is missing
# 10181 is missing
# 10182 is missing
# 10183 is missing
# 10184 is missing
# 10185 is missing
# 10186 is missing
# 10187 is missing
# 10188 is missing
# 10189 is missing
# 10190 is missing
# 10191 is missing
# 10192 is missing
# 10193 is missing
# 10194 is missing
# 10195 is missing
# 10196 is missing
# 10197 is missing
# 10198 is missing
# 10199 is missing
# 10200 is missing
# 10201 is missing
# 10202 is missing
# 10203 is missing
# 10204 is missing
# 10205 is missing
# 10206 is missing
# 10207 is missing
# 10208 is missing
# 10209 is missing
# 10210 is missing
# 10211 is missing
# 10212 is missing
# 10213 is missing
# 10214 is missing
# 10215 is missing
# 10216 is missing
# 10217 is missing
# 10218 is missing
# 10219 is missing
# 10220 is missing
# 10221 is missing
# 10222 is missing
# 10223 is missing
# 10224 is missing
# 10225 is missing
# 10226 is missing
# 10227 is missing
# 10228 is missing
# 10229 is missing
# 10230 is missing
# 10231 is missing
# 10232 is missing
# 10233 is missing
# 10234 is missing
# 10235 is missing
# 10236 is missing
# 10237 is missing
# 10238 is missing
# 10239 is missing
# 10240 is missing
# 10241 is missing
# 10242 is missing
# 10243 is missing
# 10244 is missing
# 10245 is missing
# 10246 is missing
# 10247 is missing
# 10248 is missing
# 10249 is missing
# 10250 is missing
# 10251 is missing
# 10252 is missing
# 10253 is missing
# 10254 is missing
# 10255 is missing
# 10256 is missing
# 10257 is missing
# 10258 is missing
# 10259 is missing
# 10260 is missing
# 10261 is missing
# 10262 is missing
# 10263 is missing
# 10264 is missing
# 10265 is missing
# 10266 is missing
# 10267 is missing
# 10268 is missing
# 10269 is missing
# 10270 is missing
# 10271 is missing
# 10272 is missing
# 10273 is missing
# 10274 is missing
# 10275 is missing
# 10276 is missing
# 10277 is missing
# 10278 is missing
# 10279 is missing
# 10280 is missing
# 10281 is missing
# 10282 is missing
# 10283 is missing
# 10284 is missing
# 10285 is missing
# 10286 is missing
# 10287 is missing
# 10288 is missing
# 10289 is missing
# 10290 is missing
# 10291 is missing
# 10292 is missing
# 10293 is missing
# 10294 is missing
# 10295 is missing
# 10296 is missing
# 10297 is missing
# 10298 is missing
# 10299 is missing
# 10300 is missing
# 10301 is missing
# 10302 is missing
# 10303 is missing
# 10304 is missing
# 10305 is missing
# 10306 is missing
# 10307 is missing
# 10308 is missing
# 10309 is missing
# 10310 is missing
# 10311 is missing
# 10312 is missing
# 10313 is missing
# 10314 is missing
# 10315 is missing
# 10316 is missing
# 10317 is missing
# 10318 is missing
# 10319 is missing
# 10320 is missing
# 10321 is missing
# 10322 is missing
# 10323 is missing
# 10324 is missing
# 10325 is missing
# 10326 is missing
# 10327 is missing
# 10328 is missing
# 10329 is missing
# 10330 is missing
# 10331 is missing
# 10332 is missing
# 10333 is missing
# 10334 is missing
# 10335 is missing
# 10336 is missing
# 10337 is missing
# 10338 is missing
# 10339 is missing
# 10340 is missing
# 10341 is missing
# 10342 is missing
# 10343 is missing
# 10344 is missing
# 10345 is missing
# 10346 is missing
# 10347 is missing
# 10348 is missing
# 10349 is missing
# 10350 is missing
# 10351 is missing
# 10352 is missing
# 10353 is missing
# 10354 is missing
# 10355 is missing
# 10356 is missing
# 10357 is missing
# 10358 is missing
# 10359 is missing
# 10360 is missing
# 10361 is missing
# 10362 is missing
# 10363 is missing
# 10364 is missing
# 10365 is missing
# 10366 is missing
# 10367 is missing
# 10368 is missing
# 10369 is missing
# 10370 is missing
# 10371 is missing
# 10372 is missing
# 10373 is missing
# 10374 is missing
# 10375 is missing
# 10376 is missing
# 10377 is missing
# 10378 is missing
# 10379 is missing
# 10380 is missing
# 10381 is missing
# 10382 is missing
# 10383 is missing
# 10384 is missing
# 10385 is missing
# 10386 is missing
# 10387 is missing
# 10388 is missing
# 10389 is missing
# 10390 is missing
# 10391 is missing
# 10392 is missing
# 10393 is missing
# 10394 is missing
# 10395 is missing
# 10396 is missing
# 10397 is missing
# 10398 is missing
# 10399 is missing
# 10400 is missing
# 10401 is missing
# 10402 is missing
# 10403 is missing
# 10404 is missing
# 10405 is missing
# 10406 is missing
# 10407 is missing
# 10408 is missing
# 10409 is missing
# 10410 is missing
# 10411 is missing
# 10412 is missing
# 10413 is missing
# 10414 is missing
# 10415 is missing
# 10416 is missing
# 10417 is missing
# 10418 is missing
# 10419 is missing
# 10420 is missing
# 10421 is missing
# 10422 is missing
# 10423 is missing
# 10424 is missing
# 10425 is missing
# 10426 is missing
# 10427 is missing
# 10428 is missing
# 10429 is missing
# 10430 is missing
# 10431 is missing
# 10432 is missing
# 10433 is missing
# 10434 is missing
# 10435 is missing
# 10436 is missing
# 10437 is missing
# 10438 is missing
# 10439 is missing
# 10440 is missing
# 10441 is missing
# 10442 is missing
# 10443 is missing
# 10444 is missing
# 10445 is missing
# 10446 is missing
# 10447 is missing
# 10448 is missing
# 10449 is missing
# 10450 is missing
# 10451 is missing
# 10452 is missing
# 10453 is missing
# 10454 is missing
# 10455 is missing
# 10456 is missing
# 10457 is missing
# 10458 is missing
# 10459 is missing
# 10460 is missing
# 10461 is missing
# 10462 is missing
# 10463 is missing
# 10464 is missing
# 10465 is missing
# 10466 is missing
# 10467 is missing
# 10468 is missing
# 10469 is missing
# 10470 is missing
# 10471 is missing
# 10472 is missing
# 10473 is missing
# 10474 is missing
# 10475 is missing
# 10476 is missing
# 10477 is missing
# 10478 is missing
# 10479 is missing
# 10480 is missing
# 10481 is missing
# 10482 is missing
# 10483 is missing
# 10484 is missing
# 10485 is missing
# 10486 is missing
# 10487 is missing
# 10488 is missing
# 10489 is missing
# 10490 is missing
# 10491 is missing
# 10492 is missing
# 10493 is missing
# 10494 is missing
# 10495 is missing
# 10496 is missing
# 10497 is missing
# 10498 is missing
# 10499 is missing
# 10500 is missing
# 10501 is missing
# 10502 is missing
# 10503 is missing
# 10504 is missing
# 10505 is missing
# 10506 is missing
# 10507 is missing
# 10508 is missing
# 10509 is missing
# 10510 is missing
# 10511 is missing
# 10512 is missing
# 10513 is missing
# 10514 is missing
# 10515 is missing
# 10516 is missing
# 10517 is missing
# 10518 is missing
# 10519 is missing
# 10520 is missing
# 10521 is missing
# 10522 is missing
# 10523 is missing
# 10524 is missing
# 10525 is missing
# 10526 is missing
# 10527 is missing
# 10528 is missing
# 10529 is missing
# 10530 is missing
# 10531 is missing
# 10532 is missing
# 10533 is missing
# 10534 is missing
# 10535 is missing
# 10536 is missing
# 10537 is missing
# 10538 is missing
# 10539 is missing
# 10540 is missing
# 10541 is missing
# 10542 is missing
# 10543 is missing
# 10544 is missing
# 10545 is missing
# 10546 is missing
# 10547 is missing
# 10548 is missing
# 10549 is missing
# 10550 is missing
# 10551 is missing
# 10552 is missing
# 10553 is missing
# 10554 is missing
# 10555 is missing
# 10556 is missing
# 10557 is missing
# 10558 is missing
# 10559 is missing
# 10560 is missing
# 10561 is missing
# 10562 is missing
# 10563 is missing
# 10564 is missing
# 10565 is missing
# 10566 is missing
# 10567 is missing
# 10568 is missing
# 10569 is missing
# 10570 is missing
# 10571 is missing
# 10572 is missing
# 10573 is missing
# 10574 is missing
# 10575 is missing
# 10576 is missing
# 10577 is missing
# 10578 is missing
# 10579 is missing
# 10580 is missing
# 10581 is missing
# 10582 is missing
# 10583 is missing
# 10584 is missing
# 10585 is missing
# 10586 is missing
# 10587 is missing
# 10588 is missing
# 10589 is missing
# 10590 is missing
# 10591 is missing
# 10592 is missing
# 10593 is missing
# 10594 is missing
# 10595 is missing
# 10596 is missing
# 10597 is missing
# 10598 is missing
# 10599 is missing
# 10600 is missing
# 10601 is missing
# 10602 is missing
# 10603 is missing
# 10604 is missing
# 10605 is missing
# 10606 is missing
# 10607 is missing
# 10608 is missing
# 10609 is missing
# 10610 is missing
# 10611 is missing
# 10612 is missing
# 10613 is missing
# 10614 is missing
# 10615 is missing
# 10616 is missing
# 10617 is missing
# 10618 is missing
# 10619 is missing
# 10620 is missing
# 10621 is missing
# 10622 is missing
# 10623 is missing
# 10624 is missing
# 10625 is missing
# 10626 is missing
# 10627 is missing
# 10628 is missing
# 10629 is missing
# 10630 is missing
# 10631 is missing
# 10632 is missing
# 10633 is missing
# 10634 is missing
# 10635 is missing
# 10636 is missing
# 10637 is missing
# 10638 is missing
# 10639 is missing
# 10640 is missing
# 10641 is missing
# 10642 is missing
# 10643 is missing
# 10644 is missing
# 10645 is missing
# 10646 is missing
# 10647 is missing
# 10648 is missing
# 10649 is missing
# 10650 is missing
# 10651 is missing
# 10652 is missing
# 10653 is missing
# 10654 is missing
# 10655 is missing
# 10656 is missing
# 10657 is missing
# 10658 is missing
# 10659 is missing
# 10660 is missing
# 10661 is missing
# 10662 is missing
# 10663 is missing
# 10664 is missing
# 10665 is missing
# 10666 is missing
# 10667 is missing
# 10668 is missing
# 10669 is missing
# 10670 is missing
# 10671 is missing
# 10672 is missing
# 10673 is missing
# 10674 is missing
# 10675 is missing
# 10676 is missing
# 10677 is missing
# 10678 is missing
# 10679 is missing
# 10680 is missing
# 10681 is missing
# 10682 is missing
# 10683 is missing
# 10684 is missing
# 10685 is missing
# 10686 is missing
# 10687 is missing
# 10688 is missing
# 10689 is missing
# 10690 is missing
# 10691 is missing
# 10692 is missing
# 10693 is missing
# 10694 is missing
# 10695 is missing
# 10696 is missing
# 10697 is missing
# 10698 is missing
# 10699 is missing
# 10700 is missing
# 10701 is missing
# 10702 is missing
# 10703 is missing
# 10704 is missing
# 10705 is missing
# 10706 is missing
# 10707 is missing
# 10708 is missing
# 10709 is missing
# 10710 is missing
# 10711 is missing
# 10712 is missing
# 10713 is missing
# 10714 is missing
# 10715 is missing
# 10716 is missing
# 10717 is missing
# 10718 is missing
# 10719 is missing
# 10720 is missing
# 10721 is missing
# 10722 is missing
# 10723 is missing
# 10724 is missing
# 10725 is missing
# 10726 is missing
# 10727 is missing
# 10728 is missing
# 10729 is missing
# 10730 is missing
# 10731 is missing
# 10732 is missing
# 10733 is missing
# 10734 is missing
# 10735 is missing
# 10736 is missing
# 10737 is missing
# 10738 is missing
# 10739 is missing
# 10740 is missing
# 10741 is missing
# 10742 is missing
# 10743 is missing
# 10744 is missing
# 10745 is missing
# 10746 is missing
# 10747 is missing
# 10748 is missing
# 10749 is missing
# 10750 is missing
# 10751 is missing
# 10752 is missing
# 10753 is missing
# 10754 is missing
# 10755 is missing
# 10756 is missing
# 10757 is missing
# 10758 is missing
# 10759 is missing
# 10760 is missing
# 10761 is missing
# 10762 is missing
# 10763 is missing
# 10764 is missing
# 10765 is missing
# 10766 is missing
# 10767 is missing
# 10768 is missing
# 10769 is missing
# 10770 is missing
# 10771 is missing
# 10772 is missing
# 10773 is missing
# 10774 is missing
# 10775 is missing
# 10776 is missing
# 10777 is missing
# 10778 is missing
# 10779 is missing
# 10780 is missing
# 10781 is missing
# 10782 is missing
# 10783 is missing
# 10784 is missing
# 10785 is missing
# 10786 is missing
# 10787 is missing
# 10788 is missing
# 10789 is missing
# 10790 is missing
# 10791 is missing
# 10792 is missing
# 10793 is missing
# 10794 is missing
# 10795 is missing
# 10796 is missing
# 10797 is missing
# 10798 is missing
# 10799 is missing
# 10800 is missing
# 10801 is missing
# 10802 is missing
# 10803 is missing
# 10804 is missing
# 10805 is missing
# 10806 is missing
# 10807 is missing
# 10808 is missing
# 10809 is missing
# 10810 is missing
# 10811 is missing
# 10812 is missing
# 10813 is missing
# 10814 is missing
# 10815 is missing
# 10816 is missing
# 10817 is missing
# 10818 is missing
# 10819 is missing
# 10820 is missing
# 10821 is missing
# 10822 is missing
# 10823 is missing
# 10824 is missing
# 10825 is missing
# 10826 is missing
# 10827 is missing
# 10828 is missing
# 10829 is missing
# 10830 is missing
# 10831 is missing
# 10832 is missing
# 10833 is missing
# 10834 is missing
# 10835 is missing
# 10836 is missing
# 10837 is missing
# 10838 is missing
# 10839 is missing
# 10840 is missing
# 10841 is missing
# 10842 is missing
# 10843 is missing
# 10844 is missing
# 10845 is missing
# 10846 is missing
# 10847 is missing
# 10848 is missing
# 10849 is missing
# 10850 is missing
# 10851 is missing
# 10852 is missing
# 10853 is missing
# 10854 is missing
# 10855 is missing
# 10856 is missing
# 10857 is missing
# 10858 is missing
# 10859 is missing
# 10860 is missing
# 10861 is missing
# 10862 is missing
# 10863 is missing
# 10864 is missing
# 10865 is missing
# 10866 is missing
# 10867 is missing
# 10868 is missing
# 10869 is missing
# 10870 is missing
# 10871 is missing
# 10872 is missing
# 10873 is missing
# 10874 is missing
# 10875 is missing
# 10876 is missing
# 10877 is missing
# 10878 is missing
# 10879 is missing
# 10880 is missing
# 10881 is missing
# 10882 is missing
# 10883 is missing
# 10884 is missing
# 10885 is missing
# 10886 is missing
# 10887 is missing
# 10888 is missing
# 10889 is missing
# 10890 is missing
# 10891 is missing
# 10892 is missing
# 10893 is missing
# 10894 is missing
# 10895 is missing
# 10896 is missing
# 10897 is missing
# 10898 is missing
# 10899 is missing
# 10900 is missing
# 10901 is missing
# 10902 is missing
# 10903 is missing
# 10904 is missing
# 10905 is missing
# 10906 is missing
# 10907 is missing
# 10908 is missing
# 10909 is missing
# 10910 is missing
# 10911 is missing
# 10912 is missing
# 10913 is missing
# 10914 is missing
# 10915 is missing
# 10916 is missing
# 10917 is missing
# 10918 is missing
# 10919 is missing
# 10920 is missing
# 10921 is missing
# 10922 is missing
# 10923 is missing
# 10924 is missing
# 10925 is missing
# 10926 is missing
# 10927 is missing
# 10928 is missing
# 10929 is missing
# 10930 is missing
# 10931 is missing
# 10932 is missing
# 10933 is missing
# 10934 is missing
# 10935 is missing
# 10936 is missing
# 10937 is missing
# 10938 is missing
# 10939 is missing
# 10940 is missing
# 10941 is missing
# 10942 is missing
# 10943 is missing
# 10944 is missing
# 10945 is missing
# 10946 is missing
# 10947 is missing
# 10948 is missing
# 10949 is missing
# 10950 is missing
# 10951 is missing
# 10952 is missing
# 10953 is missing
# 10954 is missing
# 10955 is missing
# 10956 is missing
# 10957 is missing
# 10958 is missing
# 10959 is missing
# 10960 is missing
# 10961 is missing
# 10962 is missing
# 10963 is missing
# 10964 is missing
# 10965 is missing
# 10966 is missing
# 10967 is missing
# 10968 is missing
# 10969 is missing
# 10970 is missing
# 10971 is missing
# 10972 is missing
# 10973 is missing
# 10974 is missing
# 10975 is missing
# 10976 is missing
# 10977 is missing
# 10978 is missing
# 10979 is missing
# 10980 is missing
# 10981 is missing
# 10982 is missing
# 10983 is missing
# 10984 is missing
# 10985 is missing
# 10986 is missing
# 10987 is missing
# 10988 is missing
# 10989 is missing
# 10990 is missing
# 10991 is missing
# 10992 is missing
# 10993 is missing
# 10994 is missing
# 10995 is missing
# 10996 is missing
# 10997 is missing
# 10998 is missing
# 10999 is missing
# 11000 is missing
# 11001 is missing
# 11002 is missing
# 11003 is missing
# 11004 is missing
# 11005 is missing
# 11006 is missing
# 11007 is missing
# 11008 is missing
# 11009 is missing
# 11010 is missing
# 11011 is missing
# 11012 is missing
# 11013 is missing
# 11014 is missing
# 11015 is missing
# 11016 is missing
# 11017 is missing
# 11018 is missing
# 11019 is missing
# 11020 is missing
# 11021 is missing
# 11022 is missing
# 11023 is missing
# 11024 is missing
# 11025 is missing
# 11026 is missing
# 11027 is missing
# 11028 is missing
# 11029 is missing
# 11030 is missing
# 11031 is missing
# 11032 is missing
# 11033 is missing
# 11034 is missing
# 11035 is missing
# 11036 is missing
# 11037 is missing
# 11038 is missing
# 11039 is missing
# 11040 is missing
# 11041 is missing
# 11042 is missing
# 11043 is missing
# 11044 is missing
# 11045 is missing
# 11046 is missing
# 11047 is missing
# 11048 is missing
# 11049 is missing
# 11050 is missing
# 11051 is missing
# 11052 is missing
# 11053 is missing
# 11054 is missing
# 11055 is missing
# 11056 is missing
# 11057 is missing
# 11058 is missing
# 11059 is missing
# 11060 is missing
# 11061 is missing
# 11062 is missing
# 11063 is missing
# 11064 is missing
# 11065 is missing
# 11066 is missing
# 11067 is missing
# 11068 is missing
# 11069 is missing
# 11070 is missing
# 11071 is missing
# 11072 is missing
# 11073 is missing
# 11074 is missing
# 11075 is missing
# 11076 is missing
# 11077 is missing
# 11078 is missing
# 11079 is missing
# 11080 is missing
# 11081 is missing
# 11082 is missing
# 11083 is missing
# 11084 is missing
# 11085 is missing
# 11086 is missing
# 11087 is missing
# 11088 is missing
# 11089 is missing
# 11090 is missing
# 11091 is missing
# 11092 is missing
# 11093 is missing
# 11094 is missing
# 11095 is missing
# 11096 is missing
# 11097 is missing
# 11098 is missing
# 11099 is missing
# 11100 is missing
# 11101 is missing
# 11102 is missing
# 11103 is missing
# 11104 is missing
# 11105 is missing
# 11106 is missing
# 11107 is missing
# 11108 is missing
# 11109 is missing
# 11110 is missing
# 11111 is missing
# 11112 is missing
# 11113 is missing
# 11114 is missing
# 11115 is missing
# 11116 is missing
# 11117 is missing
# 11118 is missing
# 11119 is missing
# 11120 is missing
# 11121 is missing
# 11122 is missing
# 11123 is missing
# 11124 is missing
# 11125 is missing
# 11126 is missing
# 11127 is missing
# 11128 is missing
# 11129 is missing
# 11130 is missing
# 11131 is missing
# 11132 is missing
# 11133 is missing
# 11134 is missing
# 11135 is missing
# 11136 is missing
# 11137 is missing
# 11138 is missing
# 11139 is missing
# 11140 is missing
# 11141 is missing
# 11142 is missing
# 11143 is missing
# 11144 is missing
# 11145 is missing
# 11146 is missing
# 11147 is missing
# 11148 is missing
# 11149 is missing
# 11150 is missing
# 11151 is missing
# 11152 is missing
# 11153 is missing
# 11154 is missing
# 11155 is missing
# 11156 is missing
# 11157 is missing
# 11158 is missing
# 11159 is missing
# 11160 is missing
# 11161 is missing
# 11162 is missing
# 11163 is missing
# 11164 is missing
# 11165 is missing
# 11166 is missing
# 11167 is missing
# 11168 is missing
# 11169 is missing
# 11170 is missing
# 11171 is missing
# 11172 is missing
# 11173 is missing
# 11174 is missing
# 11175 is missing
# 11176 is missing
# 11177 is missing
# 11178 is missing
# 11179 is missing
# 11180 is missing
# 11181 is missing
# 11182 is missing
# 11183 is missing
# 11184 is missing
# 11185 is missing
# 11186 is missing
# 11187 is missing
# 11188 is missing
# 11189 is missing
# 11190 is missing
# 11191 is missing
# 11192 is missing
# 11193 is missing
# 11194 is missing
# 11195 is missing
# 11196 is missing
# 11197 is missing
# 11198 is missing
# 11199 is missing
# 11200 is missing
# 11201 is missing
# 11202 is missing
# 11203 is missing
# 11204 is missing
# 11205 is missing
# 11206 is missing
# 11207 is missing
# 11208 is missing
# 11209 is missing
# 11210 is missing
# 11211 is missing
# 11212 is missing
# 11213 is missing
# 11214 is missing
# 11215 is missing
# 11216 is missing
# 11217 is missing
# 11218 is missing
# 11219 is missing
# 11220 is missing
# 11221 is missing
# 11222 is missing
# 11223 is missing
# 11224 is missing
# 11225 is missing
# 11226 is missing
# 11227 is missing
# 11228 is missing
# 11229 is missing
# 11230 is missing
# 11231 is missing
# 11232 is missing
# 11233 is missing
# 11234 is missing
# 11235 is missing
# 11236 is missing
# 11237 is missing
# 11238 is missing
# 11239 is missing
# 11240 is missing
# 11241 is missing
# 11242 is missing
# 11243 is missing
# 11244 is missing
# 11245 is missing
# 11246 is missing
# 11247 is missing
# 11248 is missing
# 11249 is missing
# 11250 is missing
# 11251 is missing
# 11252 is missing
# 11253 is missing
# 11254 is missing
# 11255 is missing
# 11256 is missing
# 11257 is missing
# 11258 is missing
# 11259 is missing
# 11260 is missing
# 11261 is missing
# 11262 is missing
# 11263 is missing
# 11264 is missing
# 11265 is missing
# 11266 is missing
# 11267 is missing
# 11268 is missing
# 11269 is missing
# 11270 is missing
# 11271 is missing
# 11272 is missing
# 11273 is missing
# 11274 is missing
# 11275 is missing
# 11276 is missing
# 11277 is missing
# 11278 is missing
# 11279 is missing
# 11280 is missing
# 11281 is missing
# 11282 is missing
# 11283 is missing
# 11284 is missing
# 11285 is missing
# 11286 is missing
# 11287 is missing
# 11288 is missing
# 11289 is missing
# 11290 is missing
# 11291 is missing
# 11292 is missing
# 11293 is missing
# 11294 is missing
# 11295 is missing
# 11296 is missing
# 11297 is missing
# 11298 is missing
# 11299 is missing
# 11300 is missing
# 11301 is missing
# 11302 is missing
# 11303 is missing
# 11304 is missing
# 11305 is missing
# 11306 is missing
# 11307 is missing
# 11308 is missing
# 11309 is missing
# 11310 is missing
# 11311 is missing
# 11312 is missing
# 11313 is missing
# 11314 is missing
# 11315 is missing
# 11316 is missing
# 11317 is missing
# 11318 is missing
# 11319 is missing
# 11320 is missing
# 11321 is missing
# 11322 is missing
# 11323 is missing
# 11324 is missing
# 11325 is missing
# 11326 is missing
# 11327 is missing
# 11328 is missing
# 11329 is missing
# 11330 is missing
# 11331 is missing
# 11332 is missing
# 11333 is missing
# 11334 is missing
# 11335 is missing
# 11336 is missing
# 11337 is missing
# 11338 is missing
# 11339 is missing
# 11340 is missing
# 11341 is missing
# 11342 is missing
# 11343 is missing
# 11344 is missing
# 11345 is missing
# 11346 is missing
# 11347 is missing
# 11348 is missing
# 11349 is missing
# 11350 is missing
# 11351 is missing
# 11352 is missing
# 11353 is missing
# 11354 is missing
# 11355 is missing
# 11356 is missing
# 11357 is missing
# 11358 is missing
# 11359 is missing
# 11360 is missing
# 11361 is missing
# 11362 is missing
# 11363 is missing
# 11364 is missing
# 11365 is missing
# 11366 is missing
# 11367 is missing
# 11368 is missing
# 11369 is missing
# 11370 is missing
# 11371 is missing
# 11372 is missing
# 11373 is missing
# 11374 is missing
# 11375 is missing
# 11376 is missing
# 11377 is missing
# 11378 is missing
# 11379 is missing
# 11380 is missing
# 11381 is missing
# 11382 is missing
# 11383 is missing
# 11384 is missing
# 11385 is missing
# 11386 is missing
# 11387 is missing
# 11388 is missing
# 11389 is missing
# 11390 is missing
# 11391 is missing
# 11392 is missing
# 11393 is missing
# 11394 is missing
# 11395 is missing
# 11396 is missing
# 11397 is missing
# 11398 is missing
# 11399 is missing
# 11400 is missing
# 11401 is missing
# 11402 is missing
# 11403 is missing
# 11404 is missing
# 11405 is missing
# 11406 is missing
# 11407 is missing
# 11408 is missing
# 11409 is missing
# 11410 is missing
# 11411 is missing
# 11412 is missing
# 11413 is missing
# 11414 is missing
# 11415 is missing
# 11416 is missing
# 11417 is missing
# 11418 is missing
# 11419 is missing
# 11420 is missing
# 11421 is missing
# 11422 is missing
# 11423 is missing
# 11424 is missing
# 11425 is missing
# 11426 is missing
# 11427 is missing
# 11428 is missing
# 11429 is missing
# 11430 is missing
# 11431 is missing
# 11432 is missing
# 11433 is missing
# 11434 is missing
# 11435 is missing
# 11436 is missing
# 11437 is missing
# 11438 is missing
# 11439 is missing
# 11440 is missing
# 11441 is missing
# 11442 is missing
# 11443 is missing
# 11444 is missing
# 11445 is missing
# 11446 is missing
# 11447 is missing
# 11448 is missing
# 11449 is missing
# 11450 is missing
# 11451 is missing
# 11452 is missing
# 11453 is missing
# 11454 is missing
# 11455 is missing
# 11456 is missing
# 11457 is missing
# 11458 is missing
# 11459 is missing
# 11460 is missing
# 11461 is missing
# 11462 is missing
# 11463 is missing
# 11464 is missing
# 11465 is missing
# 11466 is missing
# 11467 is missing
# 11468 is missing
# 11469 is missing
# 11470 is missing
# 11471 is missing
# 11472 is missing
# 11473 is missing
# 11474 is missing
# 11475 is missing
# 11476 is missing
# 11477 is missing
# 11478 is missing
# 11479 is missing
# 11480 is missing
# 11481 is missing
# 11482 is missing
# 11483 is missing
# 11484 is missing
# 11485 is missing
# 11486 is missing
# 11487 is missing
# 11488 is missing
# 11489 is missing
# 11490 is missing
# 11491 is missing
# 11492 is missing
# 11493 is missing
# 11494 is missing
# 11495 is missing
# 11496 is missing
# 11497 is missing
# 11498 is missing
# 11499 is missing
# ...
# 20211 is missing
# 20212 is missing
# 20213 is missing
# 20214 is missing
# 20215 is missing
# 20216 is missing
# 20217 is missing
# 20218 is missing
# 20219 is missing
# 20220 is missing
# 20221 is missing
# 20222 is missing
# 20223 is missing
# 20224 is missing
# 20225 is missing
# 20226 is missing
# 20227 is missing
# 20228 is missing
# 20229 is missing
# 20230 is missing
# 20231 is missing
# 20232 is missing
# 20233 is missing
# 20234 is missing
# 20235 is missing
# 20236 is missing
# 20237 is missing
# 20238 is missing
# 20239 is missing
# 20240 is missing
# 20241 is missing
# 20242 is missing
# 20243 is missing
# 20244 is missing
# 20245 is missing
# 20246 is missing
# 20247 is missing
# 20248 is missing
# 20249 is missing
# 20250 is missing
# 20251 is missing
# 20252 is missing
# 20253 is missing
# 20254 is missing
# 20255 is missing
# 20256 is missing
# 20257 is missing
# 20258 is missing
# 20259 is missing
# 20260 is missing
# 20261 is missing
# 20262 is missing
# 20263 is missing
# 20264 is missing
# 20265 is missing
# 20266 is missing
# 20267 is missing
# 20268 is missing
# 20269 is missing
# 20270 is missing
# 20271 is missing
# 20272 is missing
# 20273 is missing
# 20274 is missing
# 20275 is missing
# 20276 is missing
# 20277 is missing
# 20278 is missing
# 20279 is missing
# 20280 is missing
# 20281 is missing
# 20282 is missing
# 20283 is missing
# 20284 is missing
# 20285 is missing
# 20286 is missing
# 20287 is missing
# 20288 is missing
# 20289 is missing
# 20290 is missing
# 20291 is missing
# 20292 is missing
# 20293 is missing
# 20294 is missing
# 20295 is missing
# 20296 is missing
# 20297 is missing
# 20298 is missing
# 20299 is missing
# 20300 is missing
# 20301 is missing
# 20302 is missing
# 20303 is missing
# 20304 is missing
# 20305 is missing
# 20306 is missing
# 20307 is missing
# 20308 is missing
# 20309 is missing
# 20310 is missing
# 20311 is missing
# 20312 is missing
# 20313 is missing
# 20314 is missing
# 20315 is missing
# 20316 is missing
# 20317 is missing
# 20318 is missing
# 20319 is missing
# 20320 is missing
# 20321 is missing
# 20322 is missing
# 20323 is missing
# 20324 is missing
# 20325 is missing
# 20326 is missing
# 20327 is missing
# 20328 is missing
# 20329 is missing
# 20330 is missing
# 20331 is missing
# 20332 is missing
# 20333 is missing
# 20334 is missing
# 20335 is missing
# 20336 is missing
# 20337 is missing
# 20338 is missing
# 20339 is missing
# 20340 is missing
# 20341 is missing
# 20342 is missing
# 20343 is missing
# 20344 is missing
# 20345 is missing
# 20346 is missing
# 20347 is missing
# 20348 is missing
# 20349 is missing
# 20350 is missing
# 20351 is missing
# 20352 is missing
# 20353 is missing
# 20354 is missing
# 20355 is missing
# 20356 is missing
# 20357 is missing
# 20358 is missing
# 20359 is missing
# 20360 is missing
# 20361 is missing
# 20362 is missing
# 20363 is missing
# 20364 is missing
# 20365 is missing
# 20366 is missing
# 20367 is missing
# 20368 is missing
# 20369 is missing
# 20370 is missing
# 20371 is missing
# 20372 is missing
# 20373 is missing
# 20374 is missing
# 20375 is missing
# 20376 is missing
# 20377 is missing
# 20378 is missing
# 20379 is missing
# 20380 is missing
# 20381 is missing
# 20382 is missing
# 20383 is missing
# 20384 is missing
# 20385 is missing
# 20386 is missing
# 20387 is missing
# 20388 is missing
# 20389 is missing
# 20390 is missing
# 20391 is missing
# 20392 is missing
# 20393 is missing
# 20394 is missing
# 20395 is missing
# 20396 is missing
# 20397 is missing
# 20398 is missing
# 20399 is missing
# 20400 is missing
# 20401 is missing
# 20402 is missing
# 20403 is missing
# 20404 is missing
# 20405 is missing
# 20406 is missing
# 20407 is missing
# 20408 is missing
# 20409 is missing
# 20410 is missing
# 20411 is missing
# 20412 is missing
# 20413 is missing
# 20414 is missing
# 20415 is missing
# 20416 is missing
# 20417 is missing
# 20418 is missing
# 20419 is missing
# 20420 is missing
# 20421 is missing
# 20422 is missing
# 20423 is missing
# 20424 is missing
# 20425 is missing
# 20426 is missing
# 20427 is missing
# 20428 is missing
# 20429 is missing
# 20430 is missing
# 20431 is missing
# 20432 is missing
# 20433 is missing
# 20434 is missing
# 20435 is missing
# 20436 is missing
# 20437 is missing
# 20438 is missing
# 20439 is missing
# 20440 is missing
# 20441 is missing
# 20442 is missing
# 20443 is missing
# 20444 is missing
# 20445 is missing
# 20446 is missing
# 20447 is missing
# 20448 is missing
# 20449 is missing
# 20450 is missing
# 20451 is missing
# 20452 is missing
# 20453 is missing
# 20454 is missing
# 20455 is missing
# 20456 is missing
# 20457 is missing
# 20458 is missing
# 20459 is missing
# 20460 is missing
# 20461 is missing
# 20462 is missing
# 20463 is missing
# 20464 is missing
# 20465 is missing
# 20466 is missing
# 20467 is missing
# 20468 is missing
# 20469 is missing
# 20470 is missing
# 20471 is missing
# 20472 is missing
# 20473 is missing
# 20474 is missing
# 20475 is missing
# 20476 is missing
# 20477 is missing
# 20478 is missing
# 20479 is missing
# 20480 is missing
# 20481 is missing
# 20482 is missing
# 20483 is missing
# 20484 is missing
# 20485 is missing
# 20486 is missing
# 20487 is missing
# 20488 is missing
# 20489 is missing
# 20490 is missing
# 20491 is missing
# 20492 is missing
# 20493 is missing
# 20494 is missing
# 20495 is missing
# 20496 is missing
# 20497 is missing
# 20498 is missing
# 20499 is missing
# 20500 is missing
# 20501 is missing
# 20502 is missing
# 20503 is missing
# 20504 is missing
# 20505 is missing
# 20506 is missing
# 20507 is missing
# 20508 is missing
# 20509 is missing
# 20510 is missing
# 20511 is missing
# 20512 is missing
# 20513 is missing
# 20514 is missing
# 20515 is missing
# 20516 is missing
# 20517 is missing
# 20518 is missing
# 20519 is missing
# 20520 is missing
# 20521 is missing
# 20522 is missing
# 20523 is missing
# 20524 is missing
# 20525 is missing
# 20526 is missing
# 20527 is missing
# 20528 is missing
# 20529 is missing
# 20530 is missing
# 20531 is missing
# 20532 is missing
# 20533 is missing
# 20534 is missing
# 20535 is missing
# 20536 is missing
# 20537 is missing
# 20538 is missing
# 20539 is missing
# 20540 is missing
# 20541 is missing
# 20542 is missing
# 20543 is missing
# 20544 is missing
# 20545 is missing
# 20546 is missing
# 20547 is missing
# 20548 is missing
# 20549 is missing
# 20550 is missing
# 20551 is missing
# 20552 is missing
# 20553 is missing
# 20554 is missing
# 20555 is missing
# 20556 is missing
# 20557 is missing
# 20558 is missing
# 20559 is missing
# 20560 is missing
# 20561 is missing
# 20562 is missing
# 20563 is missing
# 20564 is missing
# 20565 is missing
# 20566 is missing
# 20567 is missing
# 20568 is missing
# 20569 is missing
# 20570 is missing
# 20571 is missing
# 20572 is missing
# 20573 is missing
# 20574 is missing
# 20575 is missing
# 20576 is missing
# 20577 is missing
# 20578 is missing
# 20579 is missing
# 20580 is missing
# 20581 is missing
# 20582 is missing
# 20583 is missing
# 20584 is missing
# 20585 is missing
# 20586 is missing
# 20587 is missing
# 20588 is missing
# 20589 is missing
# 20590 is missing
# 20591 is missing
# 20592 is missing
# 20593 is missing
# 20594 is missing
# 20595 is missing
# 20596 is missing
# 20597 is missing
# 20598 is missing
# 20599 is missing
# 20600 is missing
# 20601 is missing
# 20602 is missing
# 20603 is missing
# 20604 is missing
# 20605 is missing
# 20606 is missing
# 20607 is missing
# 20608 is missing
# 20609 is missing
# 20610 is missing
# 20611 is missing
# 20612 is missing
# 20613 is missing
# 20614 is missing
# 20615 is missing
# 20616 is missing
# 20617 is missing
# 20618 is missing
# 20619 is missing
# 20620 is missing
# 20621 is missing
# 20622 is missing
# 20623 is missing
# 20624 is missing
# 20625 is missing
# 20626 is missing
# 20627 is missing
# 20628 is missing
# 20629 is missing
# 20630 is missing
# 20631 is missing
# 20632 is missing
# 20633 is missing
# 20634 is missing
# 20635 is missing
# 20636 is missing
# 20637 is missing
# 20638 is missing
# 20639 is missing
# 20640 is missing
# 20641 is missing
# 20642 is missing
# 20643 is missing
# 20644 is missing
# 20645 is missing
# 20646 is missing
# 20647 is missing
# 20648 is missing
# 20649 is missing
# 20650 is missing
# 20651 is missing
# 20652 is missing
# 20653 is missing
# 20654 is missing
# 20655 is missing
# 20656 is missing
# 20657 is missing
# 20658 is missing
# 20659 is missing
# 20660 is missing
# 20661 is missing
# 20662 is missing
# 20663 is missing
# 20664 is missing
# 20665 is missing
# 20666 is missing
# 20667 is missing
# 20668 is missing
# 20669 is missing
# 20670 is missing
# 20671 is missing
# 20672 is missing
# 20673 is missing
# 20674 is missing
# 20675 is missing
# 20676 is missing
# 20677 is missing
# 20678 is missing
# 20679 is missing
# 20680 is missing
# 20681 is missing
# 20682 is missing
# 20683 is missing
# 20684 is missing
# 20685 is missing
# 20686 is missing
# 20687 is missing
# 20688 is missing
# 20689 is missing
# 20690 is missing
# 20691 is missing
# 20692 is missing
# 20693 is missing
# 20694 is missing
# 20695 is missing
# 20696 is missing
# 20697 is missing
# 20698 is missing
# 20699 is missing
# 20700 is missing
# 20701 is missing
# 20702 is missing
# 20703 is missing
# 20704 is missing
# 20705 is missing
# 20706 is missing
# 20707 is missing
# 20708 is missing
# 20709 is missing
# 20710 is missing
# 20711 is missing
# 20712 is missing
# 20713 is missing
# 20714 is missing
# 20715 is missing
# 20716 is missing
# 20717 is missing
# 20718 is missing
# 20719 is missing
# 20720 is missing
# 20721 is missing
# 20722 is missing
# 20723 is missing
# 20724 is missing
# 20725 is missing
# 20726 is missing
# 20727 is missing
# 20728 is missing
# 20729 is missing
# 20730 is missing
# 20731 is missing
# 20732 is missing
# 20733 is missing
# 20734 is missing
# 20735 is missing
# 20736 is missing
# 20737 is missing
# 20738 is missing
# 20739 is missing
# 20740 is missing
# 20741 is missing
# 20742 is missing
# 20743 is missing
# 20744 is missing
# 20745 is missing
# 20746 is missing
# 20747 is missing
# 20748 is missing
# 20749 is missing
# 20750 is missing
# 20751 is missing
# 20752 is missing
# 20753 is missing
# 20754 is missing
# 20755 is missing
# 20756 is missing
# 20757 is missing
# 20758 is missing
# 20759 is missing
# 20760 is missing
# 20761 is missing
# 20762 is missing
# 20763 is missing
# 20764 is missing
# 20765 is missing
# 20766 is missing
# 20767 is missing
# 20768 is missing
# 20769 is missing
# 20770 is missing
# 20771 is missing
# 20772 is missing
# 20773 is missing
# 20774 is missing
# 20775 is missing
# 20776 is missing
# 20777 is missing
# 20778 is missing
# 20779 is missing
# 20780 is missing
# 20781 is missing
# 20782 is missing
# 20783 is missing
# 20784 is missing
# 20785 is missing
# 20786 is missing
# 20787 is missing
# 20788 is missing
# 20789 is missing
# 20790 is missing
# 20791 is missing
# 20792 is missing
# 20793 is missing
# 20794 is missing
# 20795 is missing
# 20796 is missing
# 20797 is missing
# 20798 is missing
# 20799 is missing
# 20800 is missing
# 20801 is missing
# 20802 is missing
# 20803 is missing
# 20804 is missing
# 20805 is missing
# 20806 is missing
# 20807 is missing
# 20808 is missing
# 20809 is missing
# 20810 is missing
# 20811 is missing
# 20812 is missing
# 20813 is missing
# 20814 is missing
# 20815 is missing
# 20816 is missing
# 20817 is missing
# 20818 is missing
# 20819 is missing
# 20820 is missing
# 20821 is missing
# 20822 is missing
# 20823 is missing
# 20824 is missing
# 20825 is missing
# 20826 is missing
# 20827 is missing
# 20828 is missing
# 20829 is missing
# 20830 is missing
# 20831 is missing
# 20832 is missing
# 20833 is missing
# 20834 is missing
# 20835 is missing
# 20836 is missing
# 20837 is missing
# 20838 is missing
# 20839 is missing
# 20840 is missing
# 20841 is missing
# 20842 is missing
# 20843 is missing
# 20844 is missing
# 20845 is missing
# 20846 is missing
# 20847 is missing
# 20848 is missing
# 20849 is missing
# 20850 is missing
# 20851 is missing
# 20852 is missing
# 20853 is missing
# 20854 is missing
# 20855 is missing
# 20856 is missing
# 20857 is missing
# 20858 is missing
# 20859 is missing
# 20860 is missing
# 20861 is missing
# 20862 is missing
# 20863 is missing
# 20864 is missing
# 20865 is missing
# 20866 is missing
# 20867 is missing
# 20868 is missing
# 20869 is missing
# 20870 is missing
# 20871 is missing
# 20872 is missing
# 20873 is missing
# 20874 is missing
# 20875 is missing
# 20876 is missing
# 20877 is missing
# 20878 is missing
# 20879 is missing
# 20880 is missing
# 20881 is missing
# 20882 is missing
# 20883 is missing
# 20884 is missing
# 20885 is missing
# 20886 is missing
# 20887 is missing
# 20888 is missing
# 20889 is missing
# 20890 is missing
# 20891 is missing
# 20892 is missing
# 20893 is missing
# 20894 is missing
# 20895 is missing
# 20896 is missing
# 20897 is missing
# 20898 is missing
# 20899 is missing
# 20900 is missing
# 20901 is missing
# 20902 is missing
# 20903 is missing
# 20904 is missing
# 20905 is missing
# 20906 is missing
# 20907 is missing
# 20908 is missing
# 20909 is missing
# 20910 is missing
# 20911 is missing
# 20912 is missing
# 20913 is missing
# 20914 is missing
# 20915 is missing
# 20916 is missing
# 20917 is missing
# 20918 is missing
# 20919 is missing
# 20920 is missing
# 20921 is missing
# 20922 is missing
# 20923 is missing
# 20924 is missing
# 20925 is missing
# 20926 is missing
# 20927 is missing
# 20928 is missing
# 20929 is missing
# 20930 is missing
# 20931 is missing
# 20932 is missing
# 20933 is missing
# 20934 is missing
# 20935 is missing
# 20936 is missing
# 20937 is missing
# 20938 is missing
# 20939 is missing
# 20940 is missing
# 20941 is missing
# 20942 is missing
# 20943 is missing
# 20944 is missing
# 20945 is missing
# 20946 is missing
# 20947 is missing
# 20948 is missing
# 20949 is missing
# 20950 is missing
# 20951 is missing
# 20952 is missing
# 20953 is missing
# 20954 is missing
# 20955 is missing
# 20956 is missing
# 20957 is missing
# 20958 is missing
# 20959 is missing
# 20960 is missing
# 20961 is missing
# 20962 is missing
# 20963 is missing
# 20964 is missing
# 20965 is missing
# 20966 is missing
# 20967 is missing
# 20968 is missing
# 20969 is missing
# 20970 is missing
# 20971 is missing
# 20972 is missing
# 20973 is missing
# 20974 is missing
# 20975 is missing
# 20976 is missing
# 20977 is missing
# 20978 is missing
# 20979 is missing
# 20980 is missing
# 20981 is missing
# 20982 is missing
# 20983 is missing
# 20984 is missing
# 20985 is missing
# 20986 is missing
# 20987 is missing
# 20988 is missing
# 20989 is missing
# 20990 is missing
# 20991 is missing
# 20992 is missing
# 20993 is missing
# 20994 is missing
# 20995 is missing
# 20996 is missing
# 20997 is missing
# 20998 is missing
# 20999 is missing
# 21000 is missing
# 21001 is missing
# 21002 is missing
# 21003 is missing
# 21004 is missing
# 21005 is missing
# 21006 is missing
# 21007 is missing
# 21008 is missing
# 21009 is missing
# 21010 is missing
# 21011 is missing
# 21012 is missing
# 21013 is missing
# 21014 is missing
# 21015 is missing
# 21016 is missing
# 21017 is missing
# 21018 is missing
# 21019 is missing
# 21020 is missing
# 21021 is missing
# 21022 is missing
# 21023 is missing
# 21024 is missing
# 21025 is missing
# 21026 is missing
# 21027 is missing
# 21028 is missing
# 21029 is missing
# 21030 is missing
# 21031 is missing
# 21032 is missing
# 21033 is missing
# 21034 is missing
# 21035 is missing
# 21036 is missing
# 21037 is missing
# 21038 is missing
# 21039 is missing
# 21040 is missing
# 21041 is missing
# 21042 is missing
# 21043 is missing
# 21044 is missing
# 21045 is missing
# 21046 is missing
# 21047 is missing
# 21048 is missing
# 21049 is missing
# 21050 is missing
# 21051 is missing
# 21052 is missing
# 21053 is missing
# 21054 is missing
# 21055 is missing
# 21056 is missing
# 21057 is missing
# 21058 is missing
# 21059 is missing
# 21060 is missing
# 21061 is missing
# 21062 is missing
# 21063 is missing
# 21064 is missing
# 21065 is missing
# 21066 is missing
# 21067 is missing
# 21068 is missing
# 21069 is missing
# 21070 is missing
# 21071 is missing
# 21072 is missing
# 21073 is missing
# 21074 is missing
# 21075 is missing
# 21076 is missing
# 21077 is missing
# 21078 is missing
# 21079 is missing
# 21080 is missing
# 21081 is missing
# 21082 is missing
# 21083 is missing
# 21084 is missing
# 21085 is missing
# 21086 is missing
# 21087 is missing
# 21088 is missing
# 21089 is missing
# 21090 is missing
# 21091 is missing
# 21092 is missing
# 21093 is missing
# 21094 is missing
# 21095 is missing
# 21096 is missing
# 21097 is missing
# 21098 is missing
# 21099 is missing
# 21100 is missing
# 21101 is missing
# 21102 is missing
# 21103 is missing
# 21104 is missing
# 21105 is missing
# 21106 is missing
# 21107 is missing
# 21108 is missing
# 21109 is missing
# 21110 is missing
# 21111 is missing
# 21112 is missing
# 21113 is missing
# 21114 is missing
# 21115 is missing
# 21116 is missing
# 21117 is missing
# 21118 is missing
# 21119 is missing
#
# (366, 7)
#        date  T2M_MAX  T2M_MIN  PRECTOTCORR  GWETROOT  EVPTRNS  \
# 0  20000101    13.84     0.48         0.00      0.45     0.01
# 1  20000102     7.37    -2.22         0.02      0.45     0.00
# 2  20000103     0.50    -6.90        12.31      0.45     0.00
# 3  20000104     2.05   -12.32         0.00      0.45     0.00
# 4  20000105     5.31    -6.51         0.33      0.46     0.00
#
#    ALLSKY_SFC_PAR_TOT
# 0                46.1
# 1                55.3
# 2                 9.7
# 3                28.4
# 4                39.0

# %%
print(len(w_df))
# Out:
# 8594

# %%
# takes as input a dataframe whose index field is called "date" and
#   holds 8-character dates, and with columns 
#   ['T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'GWETROOT', 'EVPTRNS', 'ALLSKY_SFC_PAR_TOT']
# produces dataframe with same shape, but the values are grouped by MONTH,
#   with a particular aggregation used for each column

def create_monthly_df(df):
    df1 = df.copy()
    # convert index to datetime format    
    df1.index = pd.to_datetime(df['date'], format='%Y%m%d')
    # use 'M' for monthly, use 'W' for weekly
    df1_monthly = df1.resample('M').agg({'T2M_MAX':'mean',
                                       'T2M_MIN':'mean',
                                       'PRECTOTCORR':'sum',
                                       'GWETROOT':'mean',
                                       'EVPTRNS':'mean',
                                       'ALLSKY_SFC_PAR_TOT':'sum'})    

    # convert index back to string format YYYYMM
    df1_monthly.index = df1_monthly.index.strftime('%Y%m%d')
    
    return df1_monthly
    


print(create_monthly_df(w_df[4]).head(50))
# Out:
#             T2M_MAX    T2M_MIN  PRECTOTCORR  GWETROOT   EVPTRNS  \
# date
# 20000131   6.553871  -4.556774        22.08  0.456452  0.005161
# 20000229  11.777586  -1.560000        48.32  0.467931  0.048276
# 20000331  14.182258   0.869032       153.63  0.529032  0.202258
# 20000430  19.896333   4.384667        43.77  0.501333  0.613667
# 20000531  26.460323  12.685484        79.40  0.485806  1.300645
# 20000630  29.561000  16.036667       104.36  0.455333  1.075333
# 20000731  33.254516  20.190000       130.35  0.471935  1.356774
# 20000831  37.988387  22.292258         6.45  0.418065  0.367742
# 20000930  31.740333  14.993000        19.19  0.408000  0.038667
# 20001031  22.063871   9.725161       120.16  0.455484  0.132581
# 20001130   8.641333  -2.732000        19.08  0.489000  0.040667
# 20001231   1.824194  -8.334194        13.98  0.473226  0.001613
#
#           ALLSKY_SFC_PAR_TOT
# date
# 20000131              1443.3
# 20000229              1844.4
# 20000331              2306.7
# 20000430              3443.8
# 20000531              3898.2
# 20000630              4125.7
# 20000731              4421.8
# 20000831              4028.2
# 20000930              3220.2
# 20001031              2006.8
# 20001130              1700.2
# 20001231              1307.5

# %%
import json

df_t0 = w_df[0]
cols_narrow = df_t0.columns.values.tolist()[1:]
print(cols_narrow)

print()

df_t1 = create_monthly_df(df_t0)     # dfw['0001']
print(len(df_t1))
# print(df_t1.head())

cols_wide = []
for i in range(0,len(df_t1)):
    row = df_t1.iloc[i]
    # print(row)
    # can't use date, because it has year built in, and weeks start on different numbers...
    month_id = 'month_' + str(i).zfill(2)
    # print(date)
    for c in cols_narrow:
        cols_wide.append(month_id + '__' + c)
        
print(cols_wide)
print(len(cols_wide))
# Out:
# ['T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'GWETROOT', 'EVPTRNS', 'ALLSKY_SFC_PAR_TOT']
#
# 12
# ['month_00__T2M_MAX', 'month_00__T2M_MIN', 'month_00__PRECTOTCORR', 'month_00__GWETROOT', 'month_00__EVPTRNS', 'month_00__ALLSKY_SFC_PAR_TOT', 'month_01__T2M_MAX', 'month_01__T2M_MIN', 'month_01__PRECTOTCORR', 'month_01__GWETROOT', 'month_01__EVPTRNS', 'month_01__ALLSKY_SFC_PAR_TOT', 'month_02__T2M_MAX', 'month_02__T2M_MIN', 'month_02__PRECTOTCORR', 'month_02__GWETROOT', 'month_02__EVPTRNS', 'month_02__ALLSKY_SFC_PAR_TOT', 'month_03__T2M_MAX', 'month_03__T2M_MIN', 'month_03__PRECTOTCORR', 'month_03__GWETROOT', 'month_03__EVPTRNS', 'month_03__ALLSKY_SFC_PAR_TOT', 'month_04__T2M_MAX', 'month_04__T2M_MIN', 'month_04__PRECTOTCORR', 'month_04__GWETROOT', 'month_04__EVPTRNS', 'month_04__ALLSKY_SFC_PAR_TOT', 'month_05__T2M_MAX', 'month_05__T2M_MIN', 'month_05__PRECTOTCORR', 'month_05__GWETROOT', 'month_05__EVPTRNS', 'month_05__ALLSKY_SFC_PAR_TOT', 'month_06__T2M_MAX', 'month_06__T2M_MIN', 'month_06__PRECTOTCORR', 'month_06__GWETROOT', 'month_06__EVPTRNS', 'month_06__ALLSKY_SFC_PAR_TOT', 'month_07__T2M_MAX', 'month_07__T2M_MIN', 'month_07__PRECTOTCORR', 'month_07__GWETROOT', 'month_07__EVPTRNS', 'month_07__ALLSKY_SFC_PAR_TOT', 'month_08__T2M_MAX', 'month_08__T2M_MIN', 'month_08__PRECTOTCORR', 'month_08__GWETROOT', 'month_08__EVPTRNS', 'month_08__ALLSKY_SFC_PAR_TOT', 'month_09__T2M_MAX', 'month_09__T2M_MIN', 'month_09__PRECTOTCORR', 'month_09__GWETROOT', 'month_09__EVPTRNS', 'month_09__ALLSKY_SFC_PAR_TOT', 'month_10__T2M_MAX', 'month_10__T2M_MIN', 'month_10__PRECTOTCORR', 'month_10__GWETROOT', 'month_10__EVPTRNS', 'month_10__ALLSKY_SFC_PAR_TOT', 'month_11__T2M_MAX', 'month_11__T2M_MIN', 'month_11__PRECTOTCORR', 'month_11__GWETROOT', 'month_11__EVPTRNS', 'month_11__ALLSKY_SFC_PAR_TOT']
# 72

# %%
# starts with a df with the weekly aggregates for weather params,
# and produces a long sequence of all the MONTHLY weather values, in order corresponding to cols_wide

print(w_df[0].columns.tolist()[1:])
print(w_df[0].shape)
print(create_monthly_df(w_df[0]).shape)

def create_weather_seq_for_monthly(dfw):
    seq = []
    cols = dfw.columns.tolist()
    for i in range(0,len(dfw)):
        for c in cols:
            seq.append(dfw.iloc[i][c])
    return seq

# sanity check
dfw = create_monthly_df(w_df[0])
print(dfw.head(10))

seqw = create_weather_seq_for_monthly(dfw)
print(json.dumps(seqw, indent=4))
# Out:
# ['T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'GWETROOT', 'EVPTRNS', 'ALLSKY_SFC_PAR_TOT']
# (366, 7)
# (12, 6)
#             T2M_MAX    T2M_MIN  PRECTOTCORR  GWETROOT   EVPTRNS  \
# date
# 20000131   5.982581  -3.749355        14.74  0.617742  0.009355
# 20000229  11.609310  -0.812759        57.20  0.625862  0.098621
# 20000331  15.397419   2.484839        99.40  0.659032  0.270968
# 20000430  19.538000   5.900333        31.91  0.622333  0.754333
# 20000531  26.444839  14.440645        81.56  0.565484  1.129032
# 20000630  27.569000  16.717333       192.90  0.571667  1.365000
# 20000731  32.229677  20.251613        79.41  0.542258  1.342258
# 20000831  38.795484  23.239355         6.28  0.477742  0.137097
# 20000930  31.704667  15.760333        50.85  0.472333  0.017667
# 20001031  22.730000  10.503548       119.12  0.521613  0.156452
#
#           ALLSKY_SFC_PAR_TOT
# date
# 20000131              1472.6
# 20000229              1898.6
# 20000331              2403.0
# 20000430              3293.5
# 20000531              3699.4
# 20000630              3545.3
# 20000731              4327.3
# 20000831              4077.5
# 20000930              3166.9
# 20001031              2074.5
# [
#     5.98258064516129,
#     -3.7493548387096776,
#     14.74,
#     0.6177419354838709,
#     0.00935483870967742,
#     1472.6,
#     11.609310344827588,
#     -0.8127586206896552,
#     57.2,
#     0.6258620689655172,
#     0.09862068965517243,
#     1898.6,
#     15.397419354838709,
#     2.4848387096774194,
#     99.4,
#     0.6590322580645162,
#     0.2709677419354839,
#     2403.0,
#     19.538,
#     5.900333333333333,
#     31.91,
#     0.6223333333333334,
#     0.7543333333333333,
#     3293.5,
#     26.44483870967742,
#     14.440645161290323,
#     81.56,
#     0.565483870967742,
#     1.1290322580645162,
#     3699.4,
#     27.569000000000003,
#     16.717333333333332,
#     192.9,
#     0.5716666666666667,
#     1.365,
#     3545.3,
#     32.229677419354836,
#     20.251612903225805,
#     79.41,
#     0.5422580645161291,
#     1.342258064516129,
#     4327.3,
#     38.79548387096774,
#     23.239354838709676,
#     6.28,
#     0.477741935483871,
#     0.13709677419354838,
#     4077.5,
#     31.704666666666665,
#     15.760333333333334,
#     50.85,
#     0.4723333333333333,
#     0.017666666666666667,
#     3166.9,
#     22.73,
#     10.503548387096775,
#     119.12,
#     0.5216129032258066,
#     0.15645161290322582,
#     2074.5,
#     9.202,
#     -1.568,
#     44.73,
#     0.5903333333333334,
#     0.043000000000000003,
#     1499.2,
#     -0.29580645161290314,
#     -9.843225806451612,
#     23.27,
#     0.5880645161290323,
#     0.0006451612903225806,
#     1401.0
# ]

# %%
import time

u_df = {}   # each entry will hold a df corresponding to a weather .csv file 
dfw = {}    # each entry will hold the df corresponding to monthly aggregation of a weather .csv file
seqw = {}   # each entry will hold the "flattening" of the monthly aggregation df


for i in range(0,len(df_yscyll)):
    padded = str(i).zfill(4)
    # print(padded)
    try:
        u_df[padded] = pd.read_csv(weather_dir + wdtemplate.format(padded=padded))
    except:
        break
    # Want to have a name for the index of my dataframe
    u_df[padded].rename(columns={'Unnamed: 0': 'date'}, 
                   inplace=True)
    
    dfw[padded] = create_monthly_df(u_df[padded])
    # print(dfw.head())

    seqw[i] = create_weather_seq_for_monthly(dfw[padded])
    # print(json.dumps(dictw, indent=4)
    
    # introducing a small occassional sleep because my python kernel kept complaining about
    # exceeding some I/O threshold
    if i % 30 == 0:
        time.sleep(0.05)
        
    if i > 9000 and i % 100 == 0:
        time.sleep(0.5)
    
    if i % 500 == 0:
        print('Completed processing for index: ', i)
    
    
# sanity check
# print(json.dumps(seqw, indent=4))
# Out:
# Completed processing for index:  0
# Completed processing for index:  500
# Completed processing for index:  1000
# Completed processing for index:  1500
# Completed processing for index:  2000
# Completed processing for index:  2500
# Completed processing for index:  3000
# Completed processing for index:  3500
# Completed processing for index:  4000
# Completed processing for index:  4500
# Completed processing for index:  5000
# Completed processing for index:  5500
# Completed processing for index:  6000
# Completed processing for index:  6500
# Completed processing for index:  7000
# Completed processing for index:  7500
# Completed processing for index:  8000
# Completed processing for index:  8500
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 8>()
#       9 padded = str(i).zfill(4)
#      10 # print(padded)
# ---> 11 u_df[padded] = pd.read_csv(weather_dir + wdtemplate.format(padded=padded))
#      12 # Want to have a name for the index of my dataframe
#      13 u_df[padded].rename(columns={'Unnamed: 0': 'date'},
#      14                inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './weather_data/weather-data-for-index__8594.csv'

# %%
print(len(seqw))
print(json.dumps(seqw, indent=4))
# Out:
# 8594
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(dfw['0000'].shape)
print(len(cols_wide))
print(len(df_yscyll))
print(len(seqw[0]))
print()

df_wide_weather_monthly = pd.DataFrame.from_dict(seqw, orient='index', columns=cols_wide)

print(df_wide_weather_monthly.shape)
print()
print(df_wide_weather_monthly.head())
# Out:
# (12, 6)
# 72
# 21120
# 72
#
# (8594, 72)
#
#    month_00__T2M_MAX  month_00__T2M_MIN  month_00__PRECTOTCORR  \
# 0           5.982581          -3.749355                  14.74
# 1           6.086452          -3.769355                  17.07
# 2           4.339677          -5.088387                   5.80
# 3           9.012903          -3.157419                  16.94
# 4           6.553871          -4.556774                  22.08
#
#    month_00__GWETROOT  month_00__EVPTRNS  month_00__ALLSKY_SFC_PAR_TOT  \
# 0            0.617742           0.009355                        1472.6
# 1            0.624839           0.010645                        1452.0
# 2            0.544516           0.000323                        1339.8
# 3            0.435806           0.027419                        1454.7
# 4            0.456452           0.005161                        1443.3
#
#    month_01__T2M_MAX  month_01__T2M_MIN  month_01__PRECTOTCORR  \
# 0          11.609310          -0.812759                  57.20
# 1          11.821034          -0.674483                  55.89
# 2          10.357586          -1.745862                  50.61
# 3          13.948276          -0.542759                  56.45
# 4          11.777586          -1.560000                  48.32
#
#    month_01__GWETROOT  ...  month_10__PRECTOTCORR  month_10__GWETROOT  \
# 0            0.625862  ...                  44.73            0.590333
# 1            0.634483  ...                  43.42            0.584333
# 2            0.548276  ...                  46.37            0.588000
# 3            0.450000  ...                  29.84            0.469333
# 4            0.467931  ...                  19.08            0.489000
#
#    month_10__EVPTRNS  month_10__ALLSKY_SFC_PAR_TOT  month_11__T2M_MAX  \
# 0           0.043000                        1499.2          -0.295806
# 1           0.045000                        1490.3          -0.374839
# 2           0.024333                        1432.9          -2.274516
# 3           0.066000                        1676.7           3.532581
# 4           0.040667                        1700.2           1.824194
#
#    month_11__T2M_MIN  month_11__PRECTOTCORR  month_11__GWETROOT  \
# 0          -9.843226                  23.27            0.588065
# 1          -9.639677                  25.22            0.582903
# 2         -10.666129                  14.48            0.578387
# 3          -6.726774                  24.11            0.451290
# 4          -8.334194                  13.98            0.473226
#
#    month_11__EVPTRNS  month_11__ALLSKY_SFC_PAR_TOT
# 0           0.000645                        1401.0
# 1           0.000645                        1358.7
# 2           0.000323                        1332.0
# 3           0.004516                        1402.9
# 4           0.001613                        1307.5
#
# [5 rows x 72 columns]

# %%
sclls_file = 'state_county_lon_lat_soil.csv'

df_scsoil = pd.read_csv(soil_dir + sclls_file).drop(columns=['lon','lat'])
print(df_scsoil.shape)
# print(df_scsoil.head())

# will continue working with df_yscyll because updated DU PAGE county 
#     (and might update other things in future versions...)

df_ysc_y_soil = pd.merge(df_yscyll, df_scsoil, on=['state_name','county_name'],how='left')

df_ysc_y_soil = df_ysc_y_soil.drop(columns=['lon','lat'])

print()
print(df_ysc_y_soil.shape)
print(df_ysc_y_soil.head())
# Out:
# (557, 45)
#
# (21120, 49)
#    year  state_name county_name  yield  month      NDVI  nutr_ret_high  \
# 0  2017  WASHINGTON   KLICKITAT   31.8      1  0.122807           10.0
# 1  2017  WASHINGTON      BENTON   82.0      1  0.122807            9.0
# 2  2017  WASHINGTON      YAKIMA   60.0      1  0.122807            9.0
# 3  2017  WASHINGTON       ADAMS   66.3      1  0.261364           10.0
# 4  2017  WASHINGTON     LINCOLN   75.0      1  0.261364           10.0
#
#    suit_irrig_high_soy  AEZ_1  AEZ_2  ...  SQL_1  SQL_2  SQL_3  SQL_4  SQL_5  \
# 0               5556.0  False  False  ...  False  False  False  False  False
# 1               7901.0  False  False  ...  False  False  False  False  False
# 2               7950.0  False  False  ...  False  False  False  False  False
# 3               8293.0  False  False  ...  False  False  False  False  False
# 4               7778.0  False  False  ...  False  False  False  False  False
#
#    SQL_6  SQL_7  SQL_8  SQL_9 SQL_10
# 0  False  False   True  False  False
# 1  False   True  False  False  False
# 2  False   True  False  False  False
# 3  False  False   True  False  False
# 4  False  False   True  False  False
#
# [5 rows x 49 columns]

# %%
df_ysc_y_soil_weather_monthly = pd.concat([df_ysc_y_soil, df_wide_weather_monthly], axis='columns')

print(df_ysc_y_soil_weather_monthly.shape)
# print(df_ysc_y_soil_weather_monthly.head(10))
print(df_ysc_y_soil_weather_monthly.loc[28:32,:])
# Out:
# (21120, 121)
#     year state_name county_name  yield  month      NDVI  nutr_ret_high  \
# 28  2017    MONTANA       TOOLE   36.5      1  0.029412            9.0
# 29  2017    MONTANA      FERGUS   36.3      1  0.029412           10.0
# 30  2017    MONTANA      BLAINE   29.7      1  0.029412           10.0
# 31  2017    MONTANA  BROADWATER   47.5      1  0.029412           10.0
# 32  2017    MONTANA    CHOUTEAU   48.9      1  0.029412            9.0
#
#     suit_irrig_high_soy  AEZ_1  AEZ_2  ... month_10__PRECTOTCORR  \
# 28                  0.0  False  False  ...                  8.01
# 29                  0.0  False  False  ...                 47.95
# 30               5556.0  False  False  ...                 26.55
# 31               7778.0  False  False  ...                 19.33
# 32               7778.0  False  False  ...                 26.59
#
#    month_10__GWETROOT month_10__EVPTRNS month_10__ALLSKY_SFC_PAR_TOT  \
# 28           0.414000          0.045667                       1736.5
# 29           0.591333          0.038667                       1490.3
# 30           0.438000          0.029333                       1564.6
# 31           0.424000          0.020000                       1660.6
# 32           0.419333          0.019333                       1608.1
#
#    month_11__T2M_MAX month_11__T2M_MIN month_11__PRECTOTCORR  \
# 28          3.890323         -6.644516                  8.77
# 29         -0.944516         -9.980968                 18.01
# 30         -0.649677         -9.926774                 15.23
# 31          2.845161         -7.274516                  3.38
# 32          2.045161         -8.051613                  3.80
#
#    month_11__GWETROOT month_11__EVPTRNS month_11__ALLSKY_SFC_PAR_TOT
# 28           0.390000          0.003548                       1424.0
# 29           0.585161          0.000968                       1358.7
# 30           0.430000          0.002258                       1336.6
# 31           0.396452          0.000968                       1364.3
# 32           0.399677          0.000645                       1234.2
#
# [5 rows x 121 columns]

# %%
ml_tables_dir = './ML_data/'

ml_file = 'ML-table-monthly_ndvi.csv'

df_ysc_y_soil_weather_monthly.to_csv(ml_tables_dir + ml_file, index=False)

print('Wrote file ', ml_tables_dir + ml_file)
# Out:
# Wrote file  ./ML_data/ML-table-monthly_ndvi.csv

# %%
print(len(df_ysc_y_soil_weather_monthly))
# Out:
# 21120
